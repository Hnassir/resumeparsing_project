# %%
import pytesseract

from pdf2image import convert_from_path

#from pytesseract import Output

from PIL import Image

import pandas as pd

import spacy

import re

#import nltk
 
#import string

# %%
def pdftoimage(path):

    try:
        pages = convert_from_path(path, 600)
        for i in range(len(pages)) :
            pages[i].save('page'+ str(i) +'.jpg', 'JPEG')
        # Simple image to string
        text_data = ''
        for i in range(len(pages)):
            text=pytesseract.image_to_string(Image.open(f'page{i}.jpg'))
            text_data += text + '/n'

        return text_data

    except:
        return 'could not run correctly'

# %%
def clean_text(text):

    try:
        text=re.sub(r'/n+','/n',text)
        text=re.sub(r' +',' ',text)
        text=re.sub(r'\+',' ',text)
        text=re.sub(r'[#^&[*()|«!>”{¢‘“}^_`:;~]', '', text)

        return text.strip()
    
    except:
        return 'error raised'

# %% [markdown]
# def extract_mail(text):
#
#         match=re.search(r'[A-Za-z]+\S+@\S+',text)
#         return str(match[0]) if match else 'no email found'

# %%
def extract_mail(text):
    
    nlp = spacy.load("en_core_web_sm")
    
    doc = nlp(text)

    for ent in doc:
        if ent.like_email:
            return ent.text
        
    return 'no email found'

# %%
def extract_URL(text):
    
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    links=[]
    for ent in doc:
        if ent.like_url:
            links.append(ent.text)
    
    return links if links else 'no URL found'

# %%
def extract_phone(text):
        match=re.search(r'\+?\d[\d\s\-()]{8,15}\S{0}',text)
        return str(match[0]) if match else 'no phone number found'

# %%
def extract_name(text):

    nlp=spacy.load('en_core_web_sm')
    doc=nlp(text)

    for ent in doc.ents:
        if ent.label_=='PERSON':
            return ent.text
            
    return 'no name found'

# %%
def extract_location(text):

    nlp=spacy.load('en_core_web_sm')
    doc=nlp(text)

    country,city='',''

    for ent in doc.ents:
        if ent.label_=='GPE'and not city:
            city=ent.text
        #if ent.label_=='NORP'and not country :
           #country=ent.text

    if city and country:
        return ', '.join([city,country])
    elif city :
        return city
    elif country :
        return country
    else :
        return 'no location found'

# %%
SKILLS_DB = [
    'machine learning',
    'data science',
    'python',
    'word',
    'excel',
    'English',
    'SQL',
    'ux',
    'Power BI',
    'data analysis',
    'spanish',
    'sales growth',
    'networking',
    'strategic planning',
    'talent development',
    'HTML',
    'CSS',
    'Javascript',
    'milling',
    'autocad',
    'SAP',
    'solidworks',
    'cat grooming',
    'dog grooming',
    'customer servie',
    'dog training',
    'sales and marketing',
    'visual design',
    'customer relationshop',
    'cleaning',
    'mathematics'
    
]
 

def extract_skills(text,SKILLS_DB):
        
        found_skills=[skill for skill in SKILLS_DB if skill.lower() in text.lower()]
        return found_skills if found_skills else 'no skills found'

# %%
def extract_education(text):

    edu_keys = ['school','college','univers','academy','faculty','institute','bachelor','masters','master','licence','high school',
    'university','lycee', 'institut', 'doctorat','PhD', 'diploma', 'diplome', 'certificate', 'certification','certified', 'certifie',
    'associetes degree','Process Engineering','GED']
    

    lines=text.split('\n')
    education=[]
    for line in lines:
        for word in edu_keys:
            if word.lower() in line.lower() and line not in education:
                education.append(line.strip())
    if education:
        return education
    else :
        return 'no education history found'

# %%
keys = [
    'account manager',
    'ux designer',
    'junior ux designer',
    'senior ux designer',
    'civil engineer',
    'project engineer',
    'pet groomer',
    'event coordinator',
    'researcher',
    'Assistant'

]


def extract_exp(text,keys):

    lines=text.split('\n')
    exp=[]
    for line in lines:
        for word in keys:
            if word.lower() in line.lower() and line not in exp:
                exp.append(line.strip())
    if exp:
        return exp
    else :
        return 'no experience history found'

# %% [markdown]
# # here is an example of execution

# %%
text_data=pdftoimage("Example-1-PDF.pdf")

# %%
cleaned=clean_text(text_data)
cleaned
# Out:
# 'Michelle Smith\n\n%email@email.com J 541 754-3010 @ 1515 Pacific Ave, CA 90291 Los Angeles\n\ny\\N\n\nQ Sant Antonio ps American resumeviking.com/templates\nff xeOrlukd.com/24QSBG/9B9DM/?uid=17\n\nEmployment\n\nSep 2022 - Apr 2025 m Global Key Account Manager\nInash Oil  Petroleum, Dallas, TX\nSales performance with current clients increased by 20% following the\nimplementation 6-month account executive exchange programs to\ncompany locations abroad.\n\n Secure global RFP bids for clients totaling ten years and $800\n\na million in transaction revenue over contract terms\n\n Manage a national team of five Account Managers and twenty\naccount executives\n\n- Consistently exceeded annual sales goals during work tenure\n\n Organized committees responsible for pre-sales and after sales\nservice\n\n Brought significant growth of 16% in after market sales through\ncreation and implementation of strategic sales and marketing\nplans as well as talent management pipelines.\n\n Conceptualization and implementation of national accounts\nOrograms to increase brand visibility\n\n- Responsible for monitoring pre- and post-sales quality standards\nto ensure service excellence across the client territories\n\nDec 2018 - Aug 2022 m Regional Account Manager\nAsol Lubricants, Austin, TX\nCultivated over $550,000 in recurring account sales within 18 months.\n- Exceed target growth prospects by 28% via continuous interaction\nwith client stakeholders, to facilitate opportunity surveys\n- Post-Sales Capture intelligence data of client business needs,\nand competition products used to investigate cross-selling and\nupselling strategies customized for each client group\n- Successfully oversee all projects for current engagement by\nmonitoring commitments concerning quality, effort, cost, and\nschedule\n Hold a Zero complaint and escalation track record\n\nFeb 2015 - Nov 2017 m Account Manager at Presidion Petroleum, San Antonio, TX\nPresidion Petroleum, San Antonio, TX\nIncreased total revenue an average of 12% annually by upselling\nactivities.\n Manage $6 million in annual sales with recurring clients and hold\nwith complete PL accountability for fourteen counties in Texas.\n Drive brand management strategies yielding 12 % annual growth\nof supplementary products to key accounts\n- Recover $1 million in inactive accounts by initiating customer\nQ A meetings, demonstrations, and online client education and\n/nEducation\nApr 2014 - Jan 2017\n\nApr 2019\n\nSkills\n\nLanguages\n\nCourses\nMay 2016\n\nNov 2021\n\ntraining webinars\n\n Exoand company service offering to affiliate stores of six main key\naccounts which doubled client soent turnover\n\n Decrease transportation costs bay securing service level\nagreements with local transport providers\n\n Conduct client interviews for testimonial and referral purposes\n\nBachelor Degree in Advertising and Marketing\nUniversity of Denver, Denver\n\nAdvanced Diploma in Global Customer Relationship Management\nBusiness College of New York, Brooklyn\n\nClient Relationship Management Team Leadership\nGee \n\nStrategic Planning Networking\nod Ca\nTalent Development Sales Growth\n\nEEE oa om\nEnglish Spanish\n\n—a———NEOETeeseee—eerereeeQqyr eeeeeeeeee mee eScoa\\  \n\nCertified Key Accounts Manager CKAM, Udemy, Online, Udemy, Online\n\nCertificate in Project Management, Certified Institute of Project Managers\nCIPM\n/n'

# %%
extract_exp(cleaned,keys)
# Out:
# ['Sep 2022 - Apr 2025 m Global Key Account Manager',
#  'Manage a national team of five Account Managers and twenty',
#  'Dec 2018 - Aug 2022 m Regional Account Manager',
#  'Feb 2015 - Nov 2017 m Account Manager at Presidion Petroleum, San Antonio, TX']

# %%
extract_skills(cleaned,SKILLS_DB)
# Out:
# ['excel',
#  'English',
#  'spanish',
#  'sales growth',
#  'networking',
#  'strategic planning',
#  'talent development',
#  'sales and marketing']

# %%
extract_education(cleaned)
# Out:
# ['Bachelor Degree in Advertising and Marketing',
#  'University of Denver, Denver',
#  'Advanced Diploma in Global Customer Relationship Management',
#  'Business College of New York, Brooklyn',
#  'Certified Key Accounts Manager CKAM, Udemy, Online, Udemy, Online',
#  'Certificate in Project Management, Certified Institute of Project Managers']

# %%
extract_location(cleaned)
# Out:
# 'Los Angeles'

# %%
extract_mail(cleaned)
# Out:
# 'email@email.com'

# %%
extract_phone(cleaned)
# Out:
# '541 754-3010 '

# %%
extract_name(cleaned)
# Out:
# 'Michelle Smith'

# %% [markdown]
# # the main function

# %%
import os

def data_extraction(folder,exp,skills):
    results=[]

    for file in os.listdir(folder):
        if file.endswith('.pdf'):
            path=os.path.join(folder,file)
            text=pdftoimage(path)
            text=clean_text(text)
            parsed={
                'file':file,
                'name':extract_name(text),
                'location':extract_location(text),
                'email':extract_mail(text),
                'phone':extract_phone(text),
                'Links':extract_URL(text),
                'skills':extract_skills(text,skills),
                'education':extract_education(text),
                'experience':extract_exp(text,exp)
            }
            
            results.append(parsed)
            
    return pd.DataFrame(results)

# %%
data_extraction('../phase1',keys,SKILLS_DB)
# Out:
#                          file             name              location  \
# 0                CV_HN-25.pdf          Ouverte          Portefeuille
# 1   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 2             EPSExamples.pdf    no name found     no location found
# 3           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 4       resume-example-12.pdf    Edmond Connor               Orlando
# 5  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 6                  resume.pdf       John Huber              New York
# 7         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  hn.nassir@gmail.com       212  06 52571477
# 1  ebrickowski@lcu.edu       123 456 - 7890
# 2       no email found  no phone number found
# 3      email@email.com          541 754-3010
# 4    example@email.com       890-555-0401\n\n
# 5      email@email.com         3868683442\n\n
# 6      email@email.com           890-555-0401
# 7      email@email.com           3868683442\n
#
#                                                Links  \
# 0                                       no URL found
# 1                     [linkedin.com/emmetbrickowsk1]
# 2                                       no URL found
# 3  [resumeviking.com/templates, xeOrlukd.com/24QS...
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
# 7                                       no URL found
#
#                                               skills  \
# 0  [python, word, SQL, ux, Power BI, HTML, CSS, SAP]
# 1  [English, networking, milling, autocad, SAP, s...
# 2                                    [python, excel]
# 3  [excel, English, spanish, sales growth, networ...
# 4  [cat grooming, dog grooming, dog training, cle...
# 5      [English, sales and marketing, visual design]
# 6                 [excel, ux, HTML, CSS, Javascript]
# 7          [English, spanish, cleaning, mathematics]
#
#                                            education  \
# 0  [» 2013 - 2018  Diplome Etatique en Ingénierie...
# 1  [LEGO City University LEGO City, DK, Bachelor ...
# 2  [Process Engineering Intern June 2021 - Septem...
# 3  [Bachelor Degree in Advertising and Marketing,...
# 4               [GED, Nashville High, Nashville, TN]
# 5  [e Managed and coordinated 160  events per yea...
# 6  [Masters Degree in Human Computer Interaction ...
# 7  [on packing records. Completed a certificate i...
#
#                                           experience
# 0                        no experience history found
# 1  [OBJECTIVE Fourth-year Civil Engineering stude...
# 2  [Undergraduate Researcher — Shah Lab September...
# 3  [Sep 2022 - Apr 2025 m Global Key Account Mana...
# 4  [PET GROOMER, Professional and personable Pet ...
# 5  [Practical Event Coordinator with 5  years exp...
# 6  [John Huber, UX Designer, Proactive and detail...
# 7  [Laboratory Inventory Assistant at Dunrea Labo...
