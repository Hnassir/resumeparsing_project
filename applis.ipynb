# %%
import pytesseract

from pdf2image import convert_from_path

from pytesseract import Output

from PIL import Image

import pandas as pd

import spacy

import re

import nltk
 
import string

# %%
def pdftoimage(path):

    try:
        pages = convert_from_path(path, 600)
        for i in range(len(pages)) :
            pages[i].save('page'+ str(i) +'.jpg', 'JPEG')
        # Simple image to string
        text_data = ''
        for i in range(len(pages)):
            text=pytesseract.image_to_string(Image.open(f'page{i}.jpg'))
            text_data += text + '/n'

        return text_data

    except:
        return 'could not run correctly'

# %%
def clean_text(text):

    try:
        text=re.sub(r'/n+','/n',text)
        text=re.sub(r' +',' ',text)
        text=re.sub(r'\+',' ',text)
        text=re.sub(r'[#^&[*()|«!>”{¢‘“}]', '', text)

        return text.strip()
    
    except:
        return 'error raised'

# %%
def extract_mail(text):

        match=re.search(r'[A-Za-z]+\S+@\S+',text)
        return str(match[0]) if match else 'no email found'

# %%
def extract_phone(text):
        match=re.search(r'\+?\d[\d\s\-()]{8,15}\S{0}',text)
        return str(match[0]) if match else 'no phone number found'

# %%
def extract_name(text):

    nlp=spacy.load('en_core_web_sm')
    doc=nlp(text)
    for ent in doc.ents:
        if ent.label_=='PERSON':
            return ent.text
    return 'no name found'

# %%
def extract_location(text):

    nlp=spacy.load('en_core_web_sm')
    doc=nlp(text)

    country,city='',''

    for ent in doc.ents:
        if ent.label_=='GPE'and not city:
            city=ent.text
        if ent.label_=='NORP'and not country :
            country=ent.text

    if city and country:
        return ', '.join([city,country])
    elif city :
        return city
    elif country :
        return country
    else :
        return 'no location found'

# %%
SKILLS_DB = [
    'machine learning',
    'data science',
    'python',
    'word',
    'excel',
    'English',
    'SQL',
    'ux designer',
    'Power BI',
    'data analysis',
    'spanish',
    'sales growth',
    'networking',
    'strategic planning',
    'talent development',
    'HTML',
    'CSS',
    'Javascript',
    'milling',
    'autocad',
    'SAP',
    'solidworks',
    'cat grooming',
    'dog grooming',
    'customer servie',
    'dog training',
    'sales and marketing',
    'visual design',
    'customer relationshop',
    'cleaning',
    'mathematics'
    
]
 

def extract_skills(text,SKILLS_DB):
    try :
        found_skills=[skill for skill in SKILLS_DB if skill.lower() in text.lower()]
        return found_skills 
    except :
        return 'no skills found'

# %%
edu_keys = [
    'school',
    'college',
    'univers',
    'academy',
    'faculty',
    'institute',
    'bachelor',
    'masters',
    'master',
    'licence',
    'high school',
    'university',
    'lycee',
    'institut',
    'doctorat',
    'PhD',
    'diploma',
    'diplome',
    'certificate',
    'certification',
    'certified',
    'certifie',
    'associetes degree'
]


def extract_education(text,edu_keys):
    try:
        lines=text.split('\n')
        education=[]
        for line in lines:
            for word in edu_keys:
                if word.lower() in line.lower() and line not in education:
                    education.append(line.strip())
        return education

    except :
        return 'no education history found'

# %%
keys = [
    'account manager',
    'ux designer',
    'junior ux designer',
    'senior ux designer',
    'civil engineer',
    'project engineer',
    'pet groomer',
    'event coordinator'

]


def extract_exp(text,keys):

    try:
        lines=text.split('\n')
        exp=[]
        for line in lines:
            for word in keys:
                if word.lower() in line.lower() and line not in exp:
                    exp.append(line.strip())
        return exp
    except:
        return 'no experience history found'

# %% [markdown]
# # here is an example of execution

# %%
text_data=pdftoimage("Example-1-PDF.pdf")

# %%
cleaned=clean_text(text_data)
cleaned
# Out:
# 'Emmet Brickowski\nebrickowski@lcu.edu  123 456 - 7890  Bricksburg, DK  linkedin.com/emmetbrickowsk1\n\nOBJECTIVE: Fourth-year Civil Engineering student seeking a job as a Project Engineer at Bricksburg Construction\n\nEDUCATION\nLEGO City University LEGO City, DK\nBachelor of Science in Civil Engineering  GPA: 3.8/4.0 Expected Graduation: June 2024\n\nRelevant Coursework: Statics, Principles of Computer-Aided Design\n\nSKILLS\ne Manufacturing: CNC and Manual Milling, Drill Press, Lathe, Band Saw, Laser Cutting, 3D Printing\ne Software: AutoCAD, SAP2000, SolidWorks, Microsoft Suite, Google Suite\ne Languages: Fluent in English, Conversational Robot\n\nWORK EXPERIENCE\n\nCivil Engineer Intern, Bricksburg Construction, Bricksburg, DK June 2022 - September 2022\ne Created pre-construction civil engineering design plans using multiple technical software programs\n\nDeveloped familiarity with federal, state, and local regulation and ensured compliance by filing for permits\n\nRead and interpreted engineering drawings and specifications, and communicated plans to multiple vendors\n\nSolved complex problems and aided project managers to ensure the successful completion of projects\n\nVisited projects at various stages, gaining exposure to the build and inspection process of new buildings\n\nPetsitter, Bricksburg, DK June 2021 - September 2021\ne@ Supervised and cared for pets, including cats, dogs, bunnies, and chickens, prioritizing animal safety and comfort\ne Fed, exercised, and administered medication as needed for pets, with precision and on specified schedules\n@ Communicated with owners through text, email, and phone call regarding the wellbeing of their animals and\nproviding updates to ensure a positive experience for owners\n\nPROJECTS\nConstruct-o-Mech, Personal Project September 2022 - November 2022\ne@ Ideated and constructed a mechatronic suit out of 20,000  bricks and pieces to effectively destroy 100  Micro\nManager robots\ne Brainstormed ideas, drafted plans in CAD, and produced a prototype for testing\ne Performed testing and analysis, including thermal and stress tests to ensure the suit could withstand forces of\nupwards of 20,000 N\ne Scaled the prototype to create the final full-size suit following the design specifications\n\nModel Bridge, Principles of Computer Aided Design, LEGO City University April 2021 - June 2021\n@ Sketched a preliminary design using engineering principles to maximize strength of the bridge and ensure\nconformity to certain design criteria\ne Converted the design to a working computer model using SAP200 to perform structural analysis\nCrafted the final model bridge using wood and glue, to produce clean and polished final result\ne Presented Model Bridge to 100  peers and engineering professionals, and won Best Elevator Pitch among 50\nprojects\n\nACTIVITIES\nClub President, LEGO City University Civil Engineers Chapter, LEGO City, DK September 2022 - Present\ne Host 6 social events per year for a group of 100  club members in order to boost club morale, unite team\nmembers, and fundraise over $2,000  needed for yearly expenses\n@ Organize 2 networking events per year, allowing club members to network with potential employers and other\nindustry professionals\n/n'

# %%
extract_exp(cleaned,keys)
# Out:
# []

# %%
extract_skills(cleaned,SKILLS_DB)
# Out:
# ['excel',
#  'English',
#  'spanish',
#  'sales growth',
#  'networking',
#  'strategic planning',
#  'talent development']

# %%
extract_education(cleaned,edu_keys)
# Out:
# ['Bachelor Degree in Advertising and Marketing',
#  'University of Denver, Denver',
#  'Advanced Diploma in Global Customer Relationship Management',
#  'Business College of New York, Brooklyn',
#  'Certified Key Accounts Manager CKAM, Udemy, Online, Udemy, Online',
#  'Certificate in Project Management, Certified Institute of Project Managers']

# %%
extract_location(cleaned)
# Out:
# 'Los Angeles, American'

# %%
extract_mail(cleaned)
# Out:
# 'email@email.com'

# %%
extract_phone(cleaned)
# Out:
# '541 754-3010 '

# %%
extract_name(cleaned)
# Out:
# 'Michelle Smith'

# %% [markdown]
# # the main function

# %%
import os

def data_extraction(folder,exp,edu,skills):
    results=[]

    for file in os.listdir(folder):
        if file.endswith('.pdf'):
            path=os.path.join(folder,file)
            text=pdftoimage(path)
            text=clean_text(text)
            parsed={
                'file':file,
                'name':extract_name(text),
                'location':extract_location(text),
                'email':extract_mail(text),
                'phone':extract_phone(text),
                'skills':extract_skills(text,skills),
                'education':extract_education(text,edu),
                'experience':extract_exp(text,exp)
            }

            results.append(parsed)
            
    return pd.DataFrame(results)

# %%
data_extraction('../phase1',keys,edu_keys,SKILLS_DB)
# Out:
#                          file             name                       location  \
# 0   EPS-Civil-Engineering.pdf               DK                     Bricksburg
# 1             EPSExamples.pdf    no name found              no location found
# 2           Example-1-PDF.pdf   Michelle Smith          Los Angeles, American
# 3       resume-example-12.pdf            Patty              Orlando, American
# 4  Resume-Template-Modern.pdf  Templates Build            Los Angeles, French
# 5                  resume.pdf       John Huber                       New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation, Spanish
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                               skills  \
# 0  [English, networking, milling, autocad, SAP, s...
# 1                                    [python, excel]
# 2  [excel, English, spanish, sales growth, networ...
# 3  [cat grooming, dog grooming, dog training, cle...
# 4      [English, sales and marketing, visual design]
# 5        [excel, ux designer, HTML, CSS, Javascript]
# 6          [English, spanish, cleaning, mathematics]
#
#                                            education  \
# 0  [LEGO City University LEGO City, DK, Bachelor ...
# 1                                                 []
# 2  [Bachelor Degree in Advertising and Marketing,...
# 3                                                 []
# 4  [A in Hotel  Event Management, University of N...
# 5  [Masters Degree in Human Computer Interaction ...
# 6  [on packing records. Completed a certificate i...
#
#                                           experience
# 0  [OBJECTIVE: Fourth-year Civil Engineering stud...
# 1                                                 []
# 2  [Sep 2022 - Apr 2025 m Global Key Account Mana...
# 3  [PET GROOMER, Professional and personable Pet ...
# 4  [Practical Event Coordinator with 5  years exp...
# 5  [John Huber, UX Designer, Proactive and detail...
# 6                                                 []
