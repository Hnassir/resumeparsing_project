# %%
import pytesseract

from pdf2image import convert_from_path

#from pytesseract import Output

from PIL import Image

import pandas as pd

import spacy

import re

import nltk
 
import string

# %%
def pdftoimage(path):

    try:
        pages = convert_from_path(path, 600)
        for i in range(len(pages)) :
            pages[i].save('page'+ str(i) +'.jpg', 'JPEG')
        # Simple image to string
        text_data = ''
        for i in range(len(pages)):
            text=pytesseract.image_to_string(Image.open(f'page{i}.jpg'))
            text_data += text + '/n'

        return text_data

    except:
        return 'could not run correctly'

# %%
def clean_text(text):

    try:
        text=re.sub(r'/n+','/n',text)
        text=re.sub(r' +',' ',text)
        text=re.sub(r'\+',' ',text)
        text=re.sub(r'[#^&[*()|«!>”{¢‘“}^_`:;~]', '', text)

        return text.strip()
    
    except:
        return 'error raised'

# %%
def extract_mail(text):
    
    nlp = spacy.load("en_core_web_sm")
    
    doc = nlp(text)

    for ent in doc:
        if ent.like_email:
            return ent.text
        
    return 'no email found'

# %%
def extract_URL(text):
    
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    links=[]
    for ent in doc:
        if ent.like_url:
            links.append(ent.text)
    
    return links if links else 'no URL found'

# %%
def extract_phone(text):
        match=re.search(r'\+?\d[\d\s\-()]{8,15}\S{0}',text)
        return str(match[0]) if match else 'no phone number found'

# %%
def extract_name(text):

    nlp=spacy.load('en_core_web_sm')
    doc=nlp(text)

    for ent in doc.ents:
        if ent.label_=='PERSON':
            return ent.text
            
    return 'no name found'

# %%
def extract_location(text):

    nlp=spacy.load('en_core_web_sm')
    doc=nlp(text)

    country,city='',''

    for ent in doc.ents:
        if ent.label_=='GPE'and not city:
            city=ent.text
        #if ent.label_=='NORP'and not country :
           #country=ent.text

    if city and country:
        return ', '.join([city,country])
    elif city :
        return city
    elif country :
        return country
    else :
        return 'no location found'

# %%
SKILLS_DB = [
    'machine learning',
    'data science',
    'python',
    'word',
    'excel',
    'english',
    'SQL',
    'ux',
    'french',
    'power bi',
    'data analysis',
    'spanish',
    'sales growth',
    'networking',
    'strategic planning',
    'talent development',
    'html',
    'css',
    'javascript',
    'milling',
    'autocad',
    'sap',
    'solidworks',
    'cat grooming',
    'dog grooming',
    'customer servie',
    'dog training',
    'sales and marketing',
    'visual design',
    'customer relationshop',
    'cleaning',
    'mathematics'
    
]
 

def extract_skills(text,skills):
    stop_words = nltk.corpus.stopwords.words('english')
    word_tokens = nltk.tokenize.word_tokenize(text)
 
    # remove the stop words
    filtered_tokens = [w for w in word_tokens if w.lower() not in stop_words and w.lower() not in string.punctuation and w.isalpha()]
 
    # generate bigrams and trigrams (such as artificial intelligence)
    bigrams_trigrams = list(map(' '.join, nltk.everygrams(filtered_tokens)))

    # we create a set to keep the results in.
    found_skills = []
 
    # we search for each token in our skills database
    for token in filtered_tokens:
        if token.lower() in SKILLS_DB and token.lower() not in found_skills:
            found_skills.append(token.lower())
 
    # we search for each bigram and trigram in our skills database
    for ngram in bigrams_trigrams:
        if ngram.lower() in SKILLS_DB and ngram.lower() not in found_skills:
            found_skills.append(ngram.lower())
 
    return set(found_skills)

# %%
def extract_education(text):

    edu_keys = ['school','college','univers','academy','faculty','institute','bachelor','masters','master','licence','high school',
    'university','lycee', 'institut', 'doctorat','PhD', 'diploma', 'diplome', 'certificate', 'certification','certified', 'certifie',
    'associetes degree','Process Engineering','GED']
    

    lines=text.split('\n')
    education=[]
    for line in lines:
        for word in edu_keys:
            if word.lower() in line.lower() and line not in education:
                education.append(line.strip()+'.')
    if education:
        return set(education)
    else :
        return 'no education history found'

# %%
keys = [
    'account manager',
    'ux designer',
    'junior ux designer',
    'senior ux designer',
    'civil engineer',
    'project engineer',
    'pet groomer',
    'event coordinator',
    'researcher',
    'Assistant'

]


def extract_exp(text,keys):

    lines=text.split('\n')
    exp=[]
    for line in lines:
        for word in keys:
            if word.lower() in line.lower() and line not in exp:
                exp.append(line.strip()+'.')
    if exp:
        return set(exp)
    else :
        return 'no experience history found'

# %% [markdown]
# # the main function

# %%
import os

def data_extraction(folder,exp,skills):
    results=[]

    for file in os.listdir(folder):
        if file.endswith('.pdf'):
            path=os.path.join(folder,file)
            text=pdftoimage(path)
            text=clean_text(text)
            parsed={
                'file':file,
                'name':extract_name(text),
                'location':extract_location(text),
                'email':extract_mail(text),
                'phone':extract_phone(text),
                'Links':extract_URL(text),
                'skills':extract_skills(text,skills),
                'education':extract_education(text),
                'experience':extract_exp(text,exp)
            }
            
            results.append(parsed)
            
    return pd.DataFrame(results)

# %%
res=data_extraction('../phase1',keys,SKILLS_DB)
res
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                     [linkedin.com/emmetbrickowsk1]
# 1                                       no URL found
# 2  [resumeviking.com/templates, xeOrlukd.com/24QS...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  {solidworks, english, networking, autocad, mil...
# 1                                    {python, excel}
# 2  {english, strategic planning, spanish, network...
# 3  {cleaning, dog training, cat grooming, dog gro...
# 4                   {french, english, visual design}
# 5                              {css, ux, javascript}
# 6          {cleaning, english, spanish, mathematics}
#
#                                            education  \
# 0  [LEGO City University LEGO City, DK, Bachelor ...
# 1  [Process Engineering Intern June 2021 - Septem...
# 2  [Bachelor Degree in Advertising and Marketing,...
# 3               [GED, Nashville High, Nashville, TN]
# 4  [e Managed and coordinated 160  events per yea...
# 5  [Masters Degree in Human Computer Interaction ...
# 6  [on packing records. Completed a certificate i...
#
#                                           experience
# 0  [OBJECTIVE Fourth-year Civil Engineering stude...
# 1  [Undergraduate Researcher — Shah Lab September...
# 2  [Sep 2022 - Apr 2025 m Global Key Account Mana...
# 3  [PET GROOMER, Professional and personable Pet ...
# 4  [Practical Event Coordinator with 5  years exp...
# 5  [John Huber, UX Designer, Proactive and detail...
# 6  [Laboratory Inventory Assistant at Dunrea Labo...

# %%
res['skills']=res['skills'].apply(lambda x: ', '.join(x) if 'found' not in x else x)
res['Links']=res['Links'].apply(lambda x: ', '.join(x) if 'found' not in x else x)
res['education']=res['education'].apply(lambda x: ', '.join(x) if 'found' not in x else x)
res['experience']=res['experience'].apply(lambda x: ', '.join(x) if 'found' not in x else x)

# %%
res
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                       linkedin.com/emmetbrickowsk1
# 1                                       no URL found
# 2  resumeviking.com/templates, xeOrlukd.com/24QSB...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  solidworks, english, networking, autocad, milling
# 1                                      python, excel
# 2  english, strategic planning, spanish, networki...
# 3  cleaning, dog training, cat grooming, dog groo...
# 4                     french, english, visual design
# 5                                css, ux, javascript
# 6            cleaning, english, spanish, mathematics
#
#                                            education  \
# 0  LEGO City University LEGO City, DK, Bachelor o...
# 1  Process Engineering Intern June 2021 - Septemb...
# 2  Bachelor Degree in Advertising and Marketing, ...
# 3                 GED, Nashville High, Nashville, TN
# 4  e Managed and coordinated 160  events per year...
# 5  Masters Degree in Human Computer Interaction H...
# 6  on packing records. Completed a certificate in...
#
#                                           experience
# 0  OBJECTIVE Fourth-year Civil Engineering studen...
# 1  Undergraduate Researcher — Shah Lab September ...
# 2  Sep 2022 - Apr 2025 m Global Key Account Manag...
# 3  PET GROOMER, Professional and personable Pet G...
# 4  Practical Event Coordinator with 5  years expe...
# 5  John Huber, UX Designer, Proactive and detaile...
# 6  Laboratory Inventory Assistant at Dunrea Labor...

# %%
res.to_csv('AllResumeParsed.csv',index=False)

# %%
data=pd.read_csv('AllResumeParsed.csv')

data
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                       linkedin.com/emmetbrickowsk1
# 1                                       no URL found
# 2  resumeviking.com/templates, xeOrlukd.com/24QSB...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  solidworks, english, networking, autocad, milling
# 1                                      python, excel
# 2  english, strategic planning, spanish, networki...
# 3  cleaning, dog training, cat grooming, dog groo...
# 4                     french, english, visual design
# 5                                css, ux, javascript
# 6            cleaning, english, spanish, mathematics
#
#                                            education  \
# 0  LEGO City University LEGO City, DK, Bachelor o...
# 1  Process Engineering Intern June 2021 - Septemb...
# 2  Bachelor Degree in Advertising and Marketing, ...
# 3                 GED, Nashville High, Nashville, TN
# 4  e Managed and coordinated 160  events per year...
# 5  Masters Degree in Human Computer Interaction H...
# 6  on packing records. Completed a certificate in...
#
#                                           experience
# 0  OBJECTIVE Fourth-year Civil Engineering studen...
# 1  Undergraduate Researcher — Shah Lab September ...
# 2  Sep 2022 - Apr 2025 m Global Key Account Manag...
# 3  PET GROOMER, Professional and personable Pet G...
# 4  Practical Event Coordinator with 5  years expe...
# 5  John Huber, UX Designer, Proactive and detaile...
# 6  Laboratory Inventory Assistant at Dunrea Labor...

# %% [markdown]
# # creating a custom NER model

# %%
# Load a spacy model and chekc if it has ner

import spacy
nlp=spacy.load('en_core_web_sm')

nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
ner=nlp.get_pipe("ner")

# training data
TRAIN_DATA = [
              ("Walmart is a leading e-commerce company", {"entities": [(0, 7, "ORG")]}),
              ("I reached Chennai yesterday.", {"entities": [(19, 28, "GPE")]}),
              ("I recently ordered a book from Amazon", {"entities": [(24,32, "ORG")]}),
              ("I was working at Jumia", {"entities": [(17,23, "ORG")]}),
              ("I ordered this from ShopClues", {"entities": [(20,29, "ORG")]}),
              ("Altran can be ordered in Amazon ", {"entities": [(0,6, "ORG")]}),
              ("I was born in Washinton", {"entities": [(14,22, "GPE")]}),
              ("I was born in New York", {"entities": [(14,22, "GPE")]}),
              ("I bought a present from Japan", {"entities": [(24,29, "GPE")]}),
              ("I work in Sony company", {"entities": [(10,14, "ORG")]}),
              ("I rented a tent in Agadir", {"entities": [(19,25, "GPE")]}),
              ("I worked before in Innovation Insitute", {"entities": [(19,38, "ORG")]}),
              ("I graduated from Engineering University", {"entities": [(17,39, "ORG")]}),
              ("I got certificated from GoMyCode", {"entities": [(25,33, "ORG")]}),
              ("certified data scientist From Udemy", {"entities": [(30,35, "ORG")]}),
              ("Flipkart started it's journey from zero", {"entities": [(0,8, "ORG")]}),
              ("I recently ordered from Max", {"entities": [(24,27, "ORG")]}),
              ("Flipkart is recognized as leader in market",{"entities": [(0,8, "ORG")]}),

              ("Master Degree on Industrial engineering from EMSI",{"entities": [(46,49, "ORG")]}),
              ("Amazon Warehouse Associate at Amazon",{"entities": [(30,36, "ORG")]}),
              ("Los Angeles, CA 90291",{"entities": [(0,12, "GPE")]}),
              ("1515 Pacific Ave, Los Angeles, CA 90291, United",{"entities": [(18,29, "GPE")]}),
              ("Event Coordinator, Bright Event Rentals, Florida",{"entities": [(19,39, "ORG")]}),
              ("A in Hotel & Event Management, University of New York, Brooklyn",{"entities": [(31,53, "ORG")]}),
              ("Amazon Warehouse Associate at Amazon, Miami Gardens",{"entities": [(38,51, "GPE")]}),
              ("Laboratory Inventory Assistant at Dunrea Laboratories",{"entities": [(34,53, "ORG")]}),
              ("Associates Degree in Logistics and Supply Chain Fundamentals,Atlanta Technical College, Atlanta",{"entities": [(61,86, "ORG")]}),
              ("UX Designer, Real Vision Group",{"entities": [(13,30, "ORG")]}),
              ("Masters Degree in Human Computer Interaction (HCI), Pratt Institute",{"entities": [(52,67, "ORG")]}),
              ("Civil Engineer Intern, Bricksburg Construction, Bricksburg, DK",{"entities": [(23,46, "ORG")]}),

              ("I recently ordered from Swiggy", {"entities": [(24,29, "ORG")]})
              ]

# %%
for _, annotations in TRAIN_DATA:
  for ent in annotations.get("entities"):
    ner.add_label(ent[2])

# %%
# Disable pipeline components you dont need to change
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
# Import requirements
import random
from spacy.util import minibatch, compounding
from pathlib import Path
from spacy.training.example import Example

# TRAINING THE MODEL
with nlp.disable_pipes(*unaffected_pipes):

  epochs = 30
  # Training for 30 iterations
  for epoch in range(epochs):

    # shuufling examples  before every iteration
    random.shuffle(TRAIN_DATA)
    losses = {}

    # batch up the examples using spaCy's minibatch
    batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        
        #texts, annotations = zip(*batch)

        for text, annotations in  batch:
                examples = []
                doc = nlp.make_doc(text)
                example = Example.from_dict(doc, annotations)
                examples.append(example)
                nlp.update(examples, drop = 0.15, losses = losses)
        
        #nlp.update(
                    #texts,  # batch of texts
                    #annotations,  # batch of annotations
                    #drop=0.5,  # dropout - make it harder to memorise data
                    #losses=losses,)
        print("Losses", losses)
# Out:
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I got certificated from GoMyCode" with entities "[(25, 33, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': np.float32(7.567063)}
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I recently ordered a book from Amazon" with entities "[(24, 32, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I was working at Jumia" with entities "[(17, 23, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': np.float32(14.667659)}
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Master Degree on Industrial engineering from EMSI" with entities "[(46, 49, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': np.float32(16.592402)}
# Losses {'ner': np.float32(18.597466)}
# Losses {'ner': np.float32(24.586155)}
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I was born in Washinton" with entities "[(14, 22, 'GPE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': np.float32(27.027187)}
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I reached Chennai yesterday." with entities "[(19, 28, 'GPE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I recently ordered from Swiggy" with entities "[(24, 29, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': np.float32(33.561165)}
# Losses {'ner': np.float32(38.778893)}
# Losses {'ner': np.float32(1.7469201)}
# Losses {'ner': np.float32(1.752007)}
# Losses {'ner': np.float32(1.9408039)}
# Losses {'ner': np.float32(2.47666)}
# Losses {'ner': np.float32(4.181725)}
# Losses {'ner': np.float32(4.1874413)}
# Losses {'ner': np.float32(5.895218)}
# Losses {'ner': np.float32(5.896227)}
# Losses {'ner': np.float32(1.9132898)}
# Losses {'ner': np.float32(1.9133431)}
# Losses {'ner': np.float32(1.9322237)}
# Losses {'ner': np.float32(1.9326199)}
# Losses {'ner': np.float32(1.9412302)}
# Losses {'ner': np.float32(5.0737715)}
# Losses {'ner': np.float32(6.3451214)}
# Losses {'ner': np.float32(6.409368)}
# Losses {'ner': np.float32(0.18902704)}
# Losses {'ner': np.float32(1.5206553)}
# Losses {'ner': np.float32(1.5211459)}
# Losses {'ner': np.float32(1.5495764)}
# Losses {'ner': np.float32(3.5435078)}
# Losses {'ner': np.float32(3.5435078)}
# Losses {'ner': np.float32(3.5435147)}
# Losses {'ner': np.float32(5.3983097)}
# Losses {'ner': np.float32(1.6918987)}
# Losses {'ner': np.float32(1.6928921)}
# Losses {'ner': np.float32(1.6928922)}
# Losses {'ner': np.float32(2.6302488)}
# Losses {'ner': np.float32(2.6360998)}
# Losses {'ner': np.float32(2.6836247)}
# Losses {'ner': np.float32(3.1225328)}
# Losses {'ner': np.float32(3.1230903)}
# Losses {'ner': np.float32(1.9789063)}
# Losses {'ner': np.float32(1.9909168)}
# Losses {'ner': np.float32(1.9976778)}
# Losses {'ner': np.float32(1.997693)}
# Losses {'ner': np.float32(3.6107876)}
# Losses {'ner': np.float32(3.6107905)}
# Losses {'ner': np.float32(3.6108084)}
# Losses {'ner': np.float32(3.6108084)}
# Losses {'ner': np.float32(8.18273e-05)}
# Losses {'ner': np.float32(8.2303326e-05)}
# Losses {'ner': np.float32(2.00245)}
# Losses {'ner': np.float32(2.282103)}
# Losses {'ner': np.float32(2.2825937)}
# Losses {'ner': np.float32(2.303821)}
# Losses {'ner': np.float32(2.3089805)}
# Losses {'ner': np.float32(2.309274)}
# Losses {'ner': np.float32(1.4571962)}
# Losses {'ner': np.float32(1.5099374)}
# Losses {'ner': np.float32(1.5102484)}
# Losses {'ner': np.float32(1.5102489)}
# Losses {'ner': np.float32(1.5102489)}
# Losses {'ner': np.float32(1.5102854)}
# Losses {'ner': np.float32(1.5107347)}
# Losses {'ner': np.float32(1.5111662)}
# Losses {'ner': np.float32(8.538848e-05)}
# Losses {'ner': np.float32(0.048030134)}
# Losses {'ner': np.float32(0.048030544)}
# Losses {'ner': np.float32(0.053064562)}
# Losses {'ner': np.float32(0.23440184)}
# Losses {'ner': np.float32(0.23443173)}
# Losses {'ner': np.float32(0.23443198)}
# Losses {'ner': np.float32(0.23443198)}
# Losses {'ner': np.float32(4.5866457e-09)}
# Losses {'ner': np.float32(0.19130665)}
# Losses {'ner': np.float32(0.19174998)}
# Losses {'ner': np.float32(0.19175024)}
# Losses {'ner': np.float32(0.1917505)}
# Losses {'ner': np.float32(0.24344939)}
# Losses {'ner': np.float32(0.24344939)}
# Losses {'ner': np.float32(0.24344958)}
# Losses {'ner': np.float32(2.3068198e-07)}
# Losses {'ner': np.float32(0.0012948889)}
# Losses {'ner': np.float32(0.003838485)}
# Losses {'ner': np.float32(0.0038542137)}
# Losses {'ner': np.float32(0.0038542303)}
# Losses {'ner': np.float32(0.0039484436)}
# Losses {'ner': np.float32(0.0040557394)}
# Losses {'ner': np.float32(0.004055747)}
# Losses {'ner': np.float32(2.0480725e-06)}
# Losses {'ner': np.float32(0.00014381965)}
# Losses {'ner': np.float32(0.024223978)}
# Losses {'ner': np.float32(0.02422403)}
# Losses {'ner': np.float32(0.024224455)}
# Losses {'ner': np.float32(0.024224455)}
# Losses {'ner': np.float32(0.024246018)}
# Losses {'ner': np.float32(0.024246037)}
# Losses {'ner': np.float32(1.9868939)}
# Losses {'ner': np.float32(1.9868942)}
# Losses {'ner': np.float32(1.9868944)}
# Losses {'ner': np.float32(2.0944285)}
# Losses {'ner': np.float32(2.094429)}
# Losses {'ner': np.float32(2.094429)}
# Losses {'ner': np.float32(2.0944586)}
# Losses {'ner': np.float32(2.0944586)}
# Losses {'ner': np.float32(7.813707e-05)}
# Losses {'ner': np.float32(1.9888582)}
# Losses {'ner': np.float32(1.9888582)}
# Losses {'ner': np.float32(1.9888582)}
# Losses {'ner': np.float32(3.94703)}
# Losses {'ner': np.float32(3.9470406)}
# Losses {'ner': np.float32(3.947048)}
# Losses {'ner': np.float32(3.9681711)}
# Losses {'ner': np.float32(5.070956e-07)}
# Losses {'ner': np.float32(5.2169764e-07)}
# Losses {'ner': np.float32(7.935077e-07)}
# Losses {'ner': np.float32(5.380648e-06)}
# Losses {'ner': np.float32(0.00010497824)}
# Losses {'ner': np.float32(0.00010572832)}
# Losses {'ner': np.float32(0.00011122878)}
# Losses {'ner': np.float32(0.00011122878)}
# Losses {'ner': np.float32(1.1457982e-07)}
# Losses {'ner': np.float32(1.4609935e-07)}
# Losses {'ner': np.float32(0.00028274365)}
# Losses {'ner': np.float32(0.0019374829)}
# Losses {'ner': np.float32(0.0022018598)}
# Losses {'ner': np.float32(0.002201902)}
# Losses {'ner': np.float32(0.0022040112)}
# Losses {'ner': np.float32(0.0022043358)}
# Losses {'ner': np.float32(7.931485e-07)}
# Losses {'ner': np.float32(0.031823702)}
# Losses {'ner': np.float32(0.031823706)}
# Losses {'ner': np.float32(0.031823725)}
# Losses {'ner': np.float32(0.031830166)}
# Losses {'ner': np.float32(0.031830538)}
# Losses {'ner': np.float32(0.03183428)}
# Losses {'ner': np.float32(0.03183429)}
# Losses {'ner': np.float32(0.00017328351)}
# Losses {'ner': np.float32(0.00017335263)}
# Losses {'ner': np.float32(0.00017335781)}
# Losses {'ner': np.float32(0.00017346357)}
# Losses {'ner': np.float32(0.00022197426)}
# Losses {'ner': np.float32(0.00024271975)}
# Losses {'ner': np.float32(0.00024283034)}
# Losses {'ner': np.float32(0.0002428477)}
# Losses {'ner': np.float32(1.0144947e-07)}
# Losses {'ner': np.float32(1.07989464e-07)}
# Losses {'ner': np.float32(1.7106946e-07)}
# Losses {'ner': np.float32(0.00062027795)}
# Losses {'ner': np.float32(0.0006203234)}
# Losses {'ner': np.float32(0.00062040065)}
# Losses {'ner': np.float32(0.00062048604)}
# Losses {'ner': np.float32(0.000620583)}
# Losses {'ner': np.float32(6.7697924e-06)}
# Losses {'ner': np.float32(6.7998412e-06)}
# Losses {'ner': np.float32(6.8305503e-06)}
# Losses {'ner': np.float32(4.308559e-05)}
# Losses {'ner': np.float32(4.3086442e-05)}
# Losses {'ner': np.float32(0.00016607733)}
# Losses {'ner': np.float32(0.00016636033)}
# Losses {'ner': np.float32(0.00016636052)}
# Losses {'ner': np.float32(6.519352e-07)}
# Losses {'ner': np.float32(2.4104884e-06)}
# Losses {'ner': np.float32(5.969297e-05)}
# Losses {'ner': np.float32(5.9694634e-05)}
# Losses {'ner': np.float32(0.00024252276)}
# Losses {'ner': np.float32(0.0002425326)}
# Losses {'ner': np.float32(0.00024275733)}
# Losses {'ner': np.float32(0.00024275736)}
# Losses {'ner': np.float32(7.864293e-05)}
# Losses {'ner': np.float32(7.97208e-05)}
# Losses {'ner': np.float32(7.99685e-05)}
# Losses {'ner': np.float32(0.000105197796)}
# Losses {'ner': np.float32(0.00012009658)}
# Losses {'ner': np.float32(0.00012009682)}
# Losses {'ner': np.float32(0.0001200969)}
# Losses {'ner': np.float32(0.0001201034)}
# Losses {'ner': np.float32(1.1651947e-08)}
# Losses {'ner': np.float32(1.4334092e-08)}
# Losses {'ner': np.float32(1.4652654e-08)}
# Losses {'ner': np.float32(1.476102e-08)}
# Losses {'ner': np.float32(2.4917881e-08)}
# Losses {'ner': np.float32(6.569244e-08)}
# Losses {'ner': np.float32(2.9249523e-07)}
# Losses {'ner': np.float32(4.0122313e-07)}
# Losses {'ner': np.float32(5.0194522e-08)}
# Losses {'ner': np.float32(5.517264e-08)}
# Losses {'ner': np.float32(6.434781e-05)}
# Losses {'ner': np.float32(6.436347e-05)}
# Losses {'ner': np.float32(6.436413e-05)}
# Losses {'ner': np.float32(6.4364285e-05)}
# Losses {'ner': np.float32(6.436506e-05)}
# Losses {'ner': np.float32(6.443182e-05)}
# Losses {'ner': np.float32(4.346242e-06)}
# Losses {'ner': np.float32(4.3785763e-06)}
# Losses {'ner': np.float32(4.381e-06)}
# Losses {'ner': np.float32(4.4040935e-06)}
# Losses {'ner': np.float32(5.097885e-06)}
# Losses {'ner': np.float32(5.0982294e-06)}
# Losses {'ner': np.float32(5.344456e-06)}
# Losses {'ner': np.float32(5.36869e-06)}
# Losses {'ner': np.float32(2.5642216e-11)}
# Losses {'ner': np.float32(8.676999e-10)}
# Losses {'ner': np.float32(1.5445305e-08)}
# Losses {'ner': np.float32(1.5874614e-08)}
# Losses {'ner': np.float32(1.6055912e-08)}
# Losses {'ner': np.float32(1.2679453e-07)}
# Losses {'ner': np.float32(1.4472762e-07)}
# Losses {'ner': np.float32(2.5161643e-07)}
# Losses {'ner': np.float32(1.807724e-07)}
# Losses {'ner': np.float32(1.008086e-06)}
# Losses {'ner': np.float32(1.0114965e-06)}
# Losses {'ner': np.float32(1.0151124e-06)}
# Losses {'ner': np.float32(1.0151616e-06)}
# Losses {'ner': np.float32(1.0216354e-06)}
# Losses {'ner': np.float32(1.2007075e-06)}
# Losses {'ner': np.float32(1.2448102e-06)}
# Losses {'ner': np.float32(3.5393335e-10)}
# Losses {'ner': np.float32(5.3881983e-09)}
# Losses {'ner': np.float32(3.6153447e-06)}
# Losses {'ner': np.float32(3.615682e-06)}
# Losses {'ner': np.float32(3.6168137e-06)}
# Losses {'ner': np.float32(3.6170968e-06)}
# Losses {'ner': np.float32(5.268794e-06)}
# Losses {'ner': np.float32(9.602838e-06)}
# Losses {'ner': np.float32(1.5588414e-09)}
# Losses {'ner': np.float32(2.2157863e-08)}
# Losses {'ner': np.float32(3.2677416e-08)}
# Losses {'ner': np.float32(3.2692657e-08)}
# Losses {'ner': np.float32(4.5003284e-07)}
# Losses {'ner': np.float32(4.5212354e-07)}
# Losses {'ner': np.float32(2.7157124e-05)}
# Losses {'ner': np.float32(2.7161255e-05)}
# Losses {'ner': np.float32(3.709772e-10)}
# Losses {'ner': np.float32(9.962076e-08)}
# Losses {'ner': np.float32(1.00859104e-07)}
# Losses {'ner': np.float32(1.0516628e-07)}
# Losses {'ner': np.float32(1.0517241e-07)}
# Losses {'ner': np.float32(6.907828e-07)}
# Losses {'ner': np.float32(7.0250115e-07)}
# Losses {'ner': np.float32(7.104458e-07)}

# %%
# saving model

output_dir='NERScapy_model'
nlp.to_disk(output_dir)

# %%
# Test data with expected entities

TEST_DATA = [
    ("Marjane is a big place to shopping", {"entities": [(0,7,"ORG")]}),
    ("I visited Korea this year", {"entities": [(11, 16, "GPE")]}),
    ("I bought some new gadgets from Aliexpress", {"entities": [(39, 49, "ORG")]}),
    ("I am driving a Toyota", {"entities": [(21, 27, "ORG")]}),
    ("I purchased a new shoes from Cotsco", {"entities": [(36, 42, "ORG")]}),
    ("washing machine are available in Netflix", {"entities": [(30, 37, "ORG")]}),
    ("I work at Infotel", {"entities": [(10, 17, "ORG")]}),
    ("I worked before in Segula", {"entities": [(20, 26, "ORG")]}),
    ("I bought a fancy dress from ZARA", {"entities": [(36, 41, "ORG")]}),
    ("I received as a present Nikon camera", {"entities": [(23, 28, "ORG")]}),
]

# %% [markdown]
# # creating a function to evaluate the model

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
    
def evaluate_model(test_data):

    nlp= spacy.load('NERScapy_model')

    true_entities = []
    pred_entities = []
    
    for text, annotations in test_data:
        doc = nlp(text)  # Use the full nlp object to obtain a Doc
        true_entities.extend(annotations["entities"])

        # Extract predicted entities
        pred_entities_in_text = [(ent.text, ent.label_) for ent in doc.ents]
        pred_entities.extend(pred_entities_in_text)

    x1=len(true_entities)
    x2=len(pred_entities)

    for i in range((x1-x2)-1,len(true_entities)-1):
        pred_entities.append('Nan')
    

    # Prepare labels for metrics
    y_true_labels = [ent[2] for ent in true_entities]
    #y_pred_labels = [ent[1] for ent in pred_entities]
    y_pred_labels = [ent[2] if idx < len(pred_entities) else 'Nan' for idx in range(len(true_entities))]



    # Handle cases with no predictions
    if not y_pred_labels:
        print("No predictions made. Precision, recall, and F1 score cannot be defined.")
        return

    # Calculate metrics
    precision = precision_score(y_true_labels, y_pred_labels, average='weighted', zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels, average='weighted', zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels, average='weighted', zero_division=0)

    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 Score: {f1:.2f}")

# %%
# Evaluating the model performance

evaluate_model(TEST_DATA)
# Out:
# Precision: 0.81
# Recall: 0.90
# F1 Score: 0.85

# %%
# Save the  model to directory
print("Saved model as : ", output_dir)
# Out:
# Saved model as :  NERScapy_model

# %% [markdown]
# # using the model to categorize dataset entities

# %%
#using model with our parsed CVs

def extract_entities(text):

    nlp = spacy.load('NERScapy_model')

    list_org=[]

    try :
        doc = nlp(text)
        list_org=[ent.text for ent in doc.ents if ent.label_=='ORG']
        return '. '.join(list_org)

    except:
        return list_org

# %%
data['edu_organisations']=[extract_entities(i) for i in data['education']]
data['exp_organisations']=[extract_entities(i) for i in data['experience']]

data
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                       linkedin.com/emmetbrickowsk1
# 1                                       no URL found
# 2  resumeviking.com/templates, xeOrlukd.com/24QSB...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  solidworks, english, networking, autocad, milling
# 1                                      python, excel
# 2  english, strategic planning, spanish, networki...
# 3  cleaning, dog training, cat grooming, dog groo...
# 4                     french, english, visual design
# 5                                css, ux, javascript
# 6            cleaning, english, spanish, mathematics
#
#                                            education  \
# 0  LEGO City University LEGO City, DK, Bachelor o...
# 1  Process Engineering Intern June 2021 - Septemb...
# 2  Bachelor Degree in Advertising and Marketing, ...
# 3                 GED, Nashville High, Nashville, TN
# 4  e Managed and coordinated 160  events per year...
# 5  Masters Degree in Human Computer Interaction H...
# 6  on packing records. Completed a certificate in...
#
#                                           experience  \
# 0  OBJECTIVE Fourth-year Civil Engineering studen...
# 1  Undergraduate Researcher — Shah Lab September ...
# 2  Sep 2022 - Apr 2025 m Global Key Account Manag...
# 3  PET GROOMER, Professional and personable Pet G...
# 4  Practical Event Coordinator with 5  years expe...
# 5  John Huber, UX Designer, Proactive and detaile...
# 6  Laboratory Inventory Assistant at Dunrea Labor...
#
#                                    edu_organisations  \
# 0  LEGO City University LEGO City, Principles of ...
# 1
# 2  University of Denver, Business College of New ...
# 3
# 4        University of New York, Business Management
# 5                    Pratt Institute New York, HTMLS
# 6  Atlanta Technical College, Southern New Hampsh...
#
#                                    exp_organisations
# 0  Bricksburg Construction, Bachelor of Science i...
# 1
# 2                            Presidion Petroleum, TX
# 3  Pet Groomer, Pet Groomer, Pet Groomer, Pet Gro...
# 4        Bright Event Rentals, Classic Party Rentals
# 5  Real Vision Group New York, SP Global New York...
# 6                                Dunrea Laboratories

# %%
data.to_csv('processNER.csv',na_rep='NaN',index=False)

# %%
df=pd.read_csv('processNER.csv')

df.fillna('unknown', inplace=True)

df
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                       linkedin.com/emmetbrickowsk1
# 1                                       no URL found
# 2  resumeviking.com/templates, xeOrlukd.com/24QSB...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  solidworks, english, networking, autocad, milling
# 1                                      python, excel
# 2  english, strategic planning, spanish, networki...
# 3  cleaning, dog training, cat grooming, dog groo...
# 4                     french, english, visual design
# 5                                css, ux, javascript
# 6            cleaning, english, spanish, mathematics
#
#                                            education  \
# 0  LEGO City University LEGO City, DK, Bachelor o...
# 1  Process Engineering Intern June 2021 - Septemb...
# 2  Bachelor Degree in Advertising and Marketing, ...
# 3                 GED, Nashville High, Nashville, TN
# 4  e Managed and coordinated 160  events per year...
# 5  Masters Degree in Human Computer Interaction H...
# 6  on packing records. Completed a certificate in...
#
#                                           experience  \
# 0  OBJECTIVE Fourth-year Civil Engineering studen...
# 1  Undergraduate Researcher — Shah Lab September ...
# 2  Sep 2022 - Apr 2025 m Global Key Account Manag...
# 3  PET GROOMER, Professional and personable Pet G...
# 4  Practical Event Coordinator with 5  years expe...
# 5  John Huber, UX Designer, Proactive and detaile...
# 6  Laboratory Inventory Assistant at Dunrea Labor...
#
#                                    edu_organisations  \
# 0  LEGO City University LEGO City, Principles of ...
# 1                                            unknown
# 2  University of Denver, Business College of New ...
# 3                                            unknown
# 4        University of New York, Business Management
# 5                    Pratt Institute New York, HTMLS
# 6  Atlanta Technical College, Southern New Hampsh...
#
#                                    exp_organisations
# 0  Bricksburg Construction, Bachelor of Science i...
# 1                                            unknown
# 2                            Presidion Petroleum, TX
# 3  Pet Groomer, Pet Groomer, Pet Groomer, Pet Gro...
# 4        Bright Event Rentals, Classic Party Rentals
# 5  Real Vision Group New York, SP Global New York...
# 6                                Dunrea Laboratories

# %% [markdown]
# # practice relationship extraction

# %%
def extract_relationship(text):

    import spacy

    nlp_NER = spacy.load('NERScapy_model')

    doc = nlp_NER(text)

    # Create a list to store extracted relationships
    relationships = []

    # Iterate through the sentences in the document
    for sent in doc.sents:
        # Iterate through the named entities (people, organizations etc.) in the sentence
        for ent in sent.ents:
            # Check if the entity has a known label and is a person or organization
            if ent.label_ in ["ORG"]:
                # Extract the relationship
                for token in sent:
                    if token.dep_ in ["attr", "nsubj", "dobj",'pobj','ROOT','compound','conj','auxpass','nummod','agent','prep','punct'] and token.text not in ent.text:
                        relationships.append((ent.text, token.text))


    lst=[]
    lst_=[]

    for i,j in relationships:
        dic={}
        dic[i]=[]
        for y,z in relationships:
            if i==y:
                dic[i].append(z)
        dic[i]=' '.join(dic[i])
        dic[i]=dic[i].split(',')
        if dic not in lst:
            lst.append(dic)

    
    for z in lst:
        for k,j in z.items(): 
            z[k]=[i.strip() for i in j ]
            z[k]=[i for i in z[k] if bool(i) == True]
            z[k]=list(set(z[k]))
        lst_.append(k+' '+' '.join(z[k]))


    relationships=[j[0] for j in relationships]

    return {
        'relation': set(relationships),
        'result': lst_
    }

# %%
from sklearn.metrics import precision_score, recall_score, f1_score

def validate_relations(predicted_entities, true_entities):

    true_entities=[item.strip() for item in true_entities.split(',')]
    
    # Convert lists to sets for comparison
    predicted_set = set(predicted_entities['relation'])
    true_set = set(true_entities)

    
    # Calculate True Positives, False Positives, and False Negatives
    true_positives = predicted_set.intersection(true_set)
    false_positives = predicted_set - true_positives
    false_negatives = true_set - true_positives

    # Calculate Precision, Recall, and F1 Score
    precision = len(true_positives) / (len(true_positives) + len(false_positives)) if (len(true_positives) + len(false_positives)) > 0 else 0
    recall = len(true_positives) / (len(true_positives) + len(false_negatives)) if (len(true_positives) + len(false_negatives)) > 0 else 0
    f1 = 2 * (precision * recall) / (precision + recall) if (precision + recall) > 0 else 0

    return {
        'precision': precision,
        'recall': recall,
        'f1_score': f1
    }

# %% [markdown]
# # testing the validation function on a sample

# %%
predected_edu=extract_relationship(df.loc[0,'education'])

predected_exp=extract_relationship(df.loc[2,'experience'])

print(predected_edu['relation'])

print(predected_exp['relation'])
# Out:
# {'Bachelor of Science in Civil Engineering', 'LEGO City University', 'Model Bridge', 'Principles of Computer Aided Design', 'LEGO City University Civil Engineers Chapter'}
# {'Manage', 'TX', 'Presidion Petroleum'}

# %%
# i will take edu_organization as our true values

true_edu=df.loc[0,'edu_organisations']

true_exp=df.loc[2,'exp_organisations']

print(true_edu)

print(true_exp)
# Out:
# LEGO City University LEGO City, Principles of Computer Aided Design, LEGO City University, LEGO City University Civil Engineers Chapter
# Presidion Petroleum, TX

# %% [markdown]
# # here the assess result

# %%
# Assess performance
performance_edu = validate_relations(predected_edu, true_edu)
performance_exp = validate_relations(predected_exp, true_exp)


# Print the results
print("Performance Metrics, education:")
print(f"Precision: {performance_edu['precision']:.2f}")
print(f"Recall: {performance_edu['recall']:.2f}")
print(f"F1 Score: {performance_edu['f1_score']:.2f}")

print()

print("Performance Metrics, experience :")
print(f"Precision: {performance_exp['precision']:.2f}")
print(f"Recall: {performance_exp['recall']:.2f}")
print(f"F1 Score: {performance_exp['f1_score']:.2f}")
# Out:
# Performance Metrics, education:
# Precision: 0.60
# Recall: 0.75
# F1 Score: 0.67
#
# Performance Metrics, experience :
# Precision: 0.67
# Recall: 1.00
# F1 Score: 0.80

# %% [markdown]
# # let's apply the function in our dataset

# %%
df
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                       linkedin.com/emmetbrickowsk1
# 1                                       no URL found
# 2  resumeviking.com/templates, xeOrlukd.com/24QSB...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  solidworks, english, networking, autocad, milling
# 1                                      python, excel
# 2  english, strategic planning, spanish, networki...
# 3  cleaning, dog training, cat grooming, dog groo...
# 4                     french, english, visual design
# 5                                css, ux, javascript
# 6            cleaning, english, spanish, mathematics
#
#                                            education  \
# 0  LEGO City University LEGO City, DK, Bachelor o...
# 1  Process Engineering Intern June 2021 - Septemb...
# 2  Bachelor Degree in Advertising and Marketing, ...
# 3                 GED, Nashville High, Nashville, TN
# 4  e Managed and coordinated 160  events per year...
# 5  Masters Degree in Human Computer Interaction H...
# 6  on packing records. Completed a certificate in...
#
#                                           experience  \
# 0  OBJECTIVE Fourth-year Civil Engineering studen...
# 1  Undergraduate Researcher — Shah Lab September ...
# 2  Sep 2022 - Apr 2025 m Global Key Account Manag...
# 3  PET GROOMER, Professional and personable Pet G...
# 4  Practical Event Coordinator with 5  years expe...
# 5  John Huber, UX Designer, Proactive and detaile...
# 6  Laboratory Inventory Assistant at Dunrea Labor...
#
#                                    edu_organisations  \
# 0  LEGO City University LEGO City, Principles of ...
# 1                                            unknown
# 2  University of Denver, Business College of New ...
# 3                                            unknown
# 4        University of New York, Business Management
# 5                    Pratt Institute New York, HTMLS
# 6  Atlanta Technical College, Southern New Hampsh...
#
#                                    exp_organisations
# 0  Bricksburg Construction, Bachelor of Science i...
# 1                                            unknown
# 2                            Presidion Petroleum, TX
# 3  Pet Groomer, Pet Groomer, Pet Groomer, Pet Gro...
# 4        Bright Event Rentals, Classic Party Rentals
# 5  Real Vision Group New York, SP Global New York...
# 6                                Dunrea Laboratories

# %%
df['edu_relations_org']=[', '.join(extract_relationship(i)['result']) for i in df['education']]

df['exp_relations_org']=[', '.join(extract_relationship(i)['result']) for i in df['experience']]

# %%
df
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                       linkedin.com/emmetbrickowsk1
# 1                                       no URL found
# 2  resumeviking.com/templates, xeOrlukd.com/24QSB...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  solidworks, english, networking, autocad, milling
# 1                                      python, excel
# 2  english, strategic planning, spanish, networki...
# 3  cleaning, dog training, cat grooming, dog groo...
# 4                     french, english, visual design
# 5                                css, ux, javascript
# 6            cleaning, english, spanish, mathematics
#
#                                            education  \
# 0  LEGO City University LEGO City, DK, Bachelor o...
# 1  Process Engineering Intern June 2021 - Septemb...
# 2  Bachelor Degree in Advertising and Marketing, ...
# 3                 GED, Nashville High, Nashville, TN
# 4  e Managed and coordinated 160  events per year...
# 5  Masters Degree in Human Computer Interaction H...
# 6  on packing records. Completed a certificate in...
#
#                                           experience  \
# 0  OBJECTIVE Fourth-year Civil Engineering studen...
# 1  Undergraduate Researcher — Shah Lab September ...
# 2  Sep 2022 - Apr 2025 m Global Key Account Manag...
# 3  PET GROOMER, Professional and personable Pet G...
# 4  Practical Event Coordinator with 5  years expe...
# 5  John Huber, UX Designer, Proactive and detaile...
# 6  Laboratory Inventory Assistant at Dunrea Labor...
#
#                                    edu_organisations  \
# 0  LEGO City University LEGO City, Principles of ...
# 1                                            unknown
# 2  University of Denver, Business College of New ...
# 3                                            unknown
# 4        University of New York, Business Management
# 5                    Pratt Institute New York, HTMLS
# 6  Atlanta Technical College, Southern New Hampsh...
#
#                                    exp_organisations  \
# 0  Bricksburg Construction, Bachelor of Science i...
# 1                                            unknown
# 2                            Presidion Petroleum, TX
# 3  Pet Groomer, Pet Groomer, Pet Groomer, Pet Gro...
# 4        Bright Event Rentals, Classic Party Rentals
# 5  Real Vision Group New York, SP Global New York...
# 6                                Dunrea Laboratories
#
#                                    edu_relations_org  \
# 0  LEGO City University Model Bridge DK 2022 - Pr...
# 1
# 2  University of Denver Advanced Diploma in Globa...
# 3
# 4  University of New York Managed coordinated 160...
# 5  Pratt, Masters Degree in Human Computer Intera...
# 6  Atlanta Technical College Managed of associate...
#
#                                    exp_relations_org
# 0  Bricksburg Construction LEGO City DK 2022 - Pr...
# 1
# 2  Manage team of five Account Managers twenty 20...
# 3  Pet Groomer Petco TN grooming training . As is...
# 4  Bright Event Rentals Coordinator Classic Party...
# 5  Real Vision Group New York make decisions with...
# 6  Dunrea Laboratories Laboratory Inventory Assis...

# %%
df.to_csv('RelationExtracted.csv',na_rep='NaN',index=False)

# %%
data_=pd.read_csv('RelationExtracted.csv')

data_.fillna('unknown', inplace=True)

data_
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                       linkedin.com/emmetbrickowsk1
# 1                                       no URL found
# 2  resumeviking.com/templates, xeOrlukd.com/24QSB...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  solidworks, english, networking, autocad, milling
# 1                                      python, excel
# 2  english, strategic planning, spanish, networki...
# 3  cleaning, dog training, cat grooming, dog groo...
# 4                     french, english, visual design
# 5                                css, ux, javascript
# 6            cleaning, english, spanish, mathematics
#
#                                            education  \
# 0  LEGO City University LEGO City, DK, Bachelor o...
# 1  Process Engineering Intern June 2021 - Septemb...
# 2  Bachelor Degree in Advertising and Marketing, ...
# 3                 GED, Nashville High, Nashville, TN
# 4  e Managed and coordinated 160  events per year...
# 5  Masters Degree in Human Computer Interaction H...
# 6  on packing records. Completed a certificate in...
#
#                                           experience  \
# 0  OBJECTIVE Fourth-year Civil Engineering studen...
# 1  Undergraduate Researcher — Shah Lab September ...
# 2  Sep 2022 - Apr 2025 m Global Key Account Manag...
# 3  PET GROOMER, Professional and personable Pet G...
# 4  Practical Event Coordinator with 5  years expe...
# 5  John Huber, UX Designer, Proactive and detaile...
# 6  Laboratory Inventory Assistant at Dunrea Labor...
#
#                                    edu_organisations  \
# 0  LEGO City University LEGO City, Principles of ...
# 1                                            unknown
# 2  University of Denver, Business College of New ...
# 3                                            unknown
# 4        University of New York, Business Management
# 5                    Pratt Institute New York, HTMLS
# 6  Atlanta Technical College, Southern New Hampsh...
#
#                                    exp_organisations  \
# 0  Bricksburg Construction, Bachelor of Science i...
# 1                                            unknown
# 2                            Presidion Petroleum, TX
# 3  Pet Groomer, Pet Groomer, Pet Groomer, Pet Gro...
# 4        Bright Event Rentals, Classic Party Rentals
# 5  Real Vision Group New York, SP Global New York...
# 6                                Dunrea Laboratories
#
#                                    edu_relations_org  \
# 0  LEGO City University Model Bridge DK 2022 - Pr...
# 1                                            unknown
# 2  University of Denver Advanced Diploma in Globa...
# 3                                            unknown
# 4  University of New York Managed coordinated 160...
# 5  Pratt, Masters Degree in Human Computer Intera...
# 6  Atlanta Technical College Managed of associate...
#
#                                    exp_relations_org
# 0  Bricksburg Construction LEGO City DK 2022 - Pr...
# 1                                            unknown
# 2  Manage team of five Account Managers twenty 20...
# 3  Pet Groomer Petco TN grooming training . As is...
# 4  Bright Event Rentals Coordinator Classic Party...
# 5  Real Vision Group New York make decisions with...
# 6  Dunrea Laboratories Laboratory Inventory Assis...
