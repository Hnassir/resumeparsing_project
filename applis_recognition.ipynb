# %%
import pytesseract

from pdf2image import convert_from_path

#from pytesseract import Output

from PIL import Image

import pandas as pd

import spacy

import re

import nltk
 
import string

# %%
def pdftoimage(path):

    try:
        pages = convert_from_path(path, 600)
        for i in range(len(pages)) :
            pages[i].save('page'+ str(i) +'.jpg', 'JPEG')
        # Simple image to string
        text_data = ''
        for i in range(len(pages)):
            text=pytesseract.image_to_string(Image.open(f'page{i}.jpg'))
            text_data += text + '/n'

        return text_data

    except:
        return 'could not run correctly'

# %%
def clean_text(text):

    try:
        text=re.sub(r'/n+','/n',text)
        text=re.sub(r' +',' ',text)
        text=re.sub(r'\+',' ',text)
        text=re.sub(r'[#^&[*()|«!>”{¢‘“}^_`:;~]', '', text)

        return text.strip()
    
    except:
        return 'error raised'

# %%
def extract_mail(text):
    
    nlp = spacy.load("en_core_web_sm")
    
    doc = nlp(text)

    for ent in doc:
        if ent.like_email:
            return ent.text
        
    return 'no email found'

# %%
def extract_URL(text):
    
    nlp = spacy.load("en_core_web_sm")
    doc = nlp(text)
    links=[]
    for ent in doc:
        if ent.like_url:
            links.append(ent.text)
    
    return links if links else 'no URL found'

# %%
def extract_phone(text):
        match=re.search(r'\+?\d[\d\s\-()]{8,15}\S{0}',text)
        return str(match[0]) if match else 'no phone number found'

# %%
def extract_name(text):

    nlp=spacy.load('en_core_web_sm')
    doc=nlp(text)

    for ent in doc.ents:
        if ent.label_=='PERSON':
            return ent.text
            
    return 'no name found'

# %%
def extract_location(text):

    nlp=spacy.load('en_core_web_sm')
    doc=nlp(text)

    country,city='',''

    for ent in doc.ents:
        if ent.label_=='GPE'and not city:
            city=ent.text
        #if ent.label_=='NORP'and not country :
           #country=ent.text

    if city and country:
        return ', '.join([city,country])
    elif city :
        return city
    elif country :
        return country
    else :
        return 'no location found'

# %%
SKILLS_DB = [
    'machine learning',
    'data science',
    'python',
    'word',
    'excel',
    'english',
    'SQL',
    'ux',
    'french',
    'power bi',
    'data analysis',
    'spanish',
    'sales growth',
    'networking',
    'strategic planning',
    'talent development',
    'html',
    'css',
    'javascript',
    'milling',
    'autocad',
    'sap',
    'solidworks',
    'cat grooming',
    'dog grooming',
    'customer servie',
    'dog training',
    'sales and marketing',
    'visual design',
    'customer relationshop',
    'cleaning',
    'mathematics'
    
]
 

def extract_skills(text,skills):
    stop_words = nltk.corpus.stopwords.words('english')
    word_tokens = nltk.tokenize.word_tokenize(text)
 
    # remove the stop words
    filtered_tokens = [w for w in word_tokens if w.lower() not in stop_words and w.lower() not in string.punctuation and w.isalpha()]
 
    # generate bigrams and trigrams (such as artificial intelligence)
    bigrams_trigrams = list(map(' '.join, nltk.everygrams(filtered_tokens)))

    # we create a set to keep the results in.
    found_skills = []
 
    # we search for each token in our skills database
    for token in filtered_tokens:
        if token.lower() in SKILLS_DB and token.lower() not in found_skills:
            found_skills.append(token.lower())
 
    # we search for each bigram and trigram in our skills database
    for ngram in bigrams_trigrams:
        if ngram.lower() in SKILLS_DB and ngram.lower() not in found_skills:
            found_skills.append(ngram.lower())
 
    return set(found_skills)

# %%
def extract_education(text):

    edu_keys = ['school','college','univers','academy','faculty','institute','bachelor','masters','master','licence','high school',
    'university','lycee', 'institut', 'doctorat','PhD', 'diploma', 'diplome', 'certificate', 'certification','certified', 'certifie',
    'associetes degree','Process Engineering','GED']
    

    lines=text.split('\n')
    education=[]
    for line in lines:
        for word in edu_keys:
            if word.lower() in line.lower() and line not in education:
                education.append(line.strip())
    if education:
        return education
    else :
        return 'no education history found'

# %%
keys = [
    'account manager',
    'ux designer',
    'junior ux designer',
    'senior ux designer',
    'civil engineer',
    'project engineer',
    'pet groomer',
    'event coordinator',
    'researcher',
    'Assistant'

]


def extract_exp(text,keys):

    lines=text.split('\n')
    exp=[]
    for line in lines:
        for word in keys:
            if word.lower() in line.lower() and line not in exp:
                exp.append(line.strip())
    if exp:
        return exp
    else :
        return 'no experience history found'

# %% [markdown]
# # the main function

# %%
import os

def data_extraction(folder,exp,skills):
    results=[]

    for file in os.listdir(folder):
        if file.endswith('.pdf'):
            path=os.path.join(folder,file)
            text=pdftoimage(path)
            text=clean_text(text)
            parsed={
                'file':file,
                'name':extract_name(text),
                'location':extract_location(text),
                'email':extract_mail(text),
                'phone':extract_phone(text),
                'Links':extract_URL(text),
                'skills':extract_skills(text,skills),
                'education':extract_education(text),
                'experience':extract_exp(text,exp)
            }
            
            results.append(parsed)
            
    return pd.DataFrame(results)

# %%
res=data_extraction('../phase1',keys,SKILLS_DB)
res
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                     [linkedin.com/emmetbrickowsk1]
# 1                                       no URL found
# 2  [resumeviking.com/templates, xeOrlukd.com/24QS...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  {solidworks, english, networking, autocad, mil...
# 1                                    {python, excel}
# 2  {english, strategic planning, spanish, network...
# 3  {cleaning, dog training, cat grooming, dog gro...
# 4                   {french, english, visual design}
# 5                              {css, ux, javascript}
# 6          {cleaning, english, spanish, mathematics}
#
#                                            education  \
# 0  [LEGO City University LEGO City, DK, Bachelor ...
# 1  [Process Engineering Intern June 2021 - Septem...
# 2  [Bachelor Degree in Advertising and Marketing,...
# 3               [GED, Nashville High, Nashville, TN]
# 4  [e Managed and coordinated 160  events per yea...
# 5  [Masters Degree in Human Computer Interaction ...
# 6  [on packing records. Completed a certificate i...
#
#                                           experience
# 0  [OBJECTIVE Fourth-year Civil Engineering stude...
# 1  [Undergraduate Researcher — Shah Lab September...
# 2  [Sep 2022 - Apr 2025 m Global Key Account Mana...
# 3  [PET GROOMER, Professional and personable Pet ...
# 4  [Practical Event Coordinator with 5  years exp...
# 5  [John Huber, UX Designer, Proactive and detail...
# 6  [Laboratory Inventory Assistant at Dunrea Labo...

# %%
res['skills']=res['skills'].apply(lambda x: ', '.join(x) if 'found' not in x else x)
res['Links']=res['Links'].apply(lambda x: ', '.join(x) if 'found' not in x else x)
res['education']=res['education'].apply(lambda x: ', '.join(x) if 'found' not in x else x)
res['experience']=res['experience'].apply(lambda x: ', '.join(x) if 'found' not in x else x)

# %%
res
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                       linkedin.com/emmetbrickowsk1
# 1                                       no URL found
# 2  resumeviking.com/templates, xeOrlukd.com/24QSB...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  solidworks, english, networking, autocad, milling
# 1                                      python, excel
# 2  english, strategic planning, spanish, networki...
# 3  cleaning, dog training, cat grooming, dog groo...
# 4                     french, english, visual design
# 5                                css, ux, javascript
# 6            cleaning, english, spanish, mathematics
#
#                                            education  \
# 0  LEGO City University LEGO City, DK, Bachelor o...
# 1  Process Engineering Intern June 2021 - Septemb...
# 2  Bachelor Degree in Advertising and Marketing, ...
# 3                 GED, Nashville High, Nashville, TN
# 4  e Managed and coordinated 160  events per year...
# 5  Masters Degree in Human Computer Interaction H...
# 6  on packing records. Completed a certificate in...
#
#                                           experience
# 0  OBJECTIVE Fourth-year Civil Engineering studen...
# 1  Undergraduate Researcher — Shah Lab September ...
# 2  Sep 2022 - Apr 2025 m Global Key Account Manag...
# 3  PET GROOMER, Professional and personable Pet G...
# 4  Practical Event Coordinator with 5  years expe...
# 5  John Huber, UX Designer, Proactive and detaile...
# 6  Laboratory Inventory Assistant at Dunrea Labor...

# %%
res.to_csv('AllResumeParsed.csv',index=False)

# %%
data=pd.read_csv('AllResumeParsed.csv')

data
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                       linkedin.com/emmetbrickowsk1
# 1                                       no URL found
# 2  resumeviking.com/templates, xeOrlukd.com/24QSB...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  solidworks, english, networking, autocad, milling
# 1                                      python, excel
# 2  english, strategic planning, spanish, networki...
# 3  cleaning, dog training, cat grooming, dog groo...
# 4                     french, english, visual design
# 5                                css, ux, javascript
# 6            cleaning, english, spanish, mathematics
#
#                                            education  \
# 0  LEGO City University LEGO City, DK, Bachelor o...
# 1  Process Engineering Intern June 2021 - Septemb...
# 2  Bachelor Degree in Advertising and Marketing, ...
# 3                 GED, Nashville High, Nashville, TN
# 4  e Managed and coordinated 160  events per year...
# 5  Masters Degree in Human Computer Interaction H...
# 6  on packing records. Completed a certificate in...
#
#                                           experience
# 0  OBJECTIVE Fourth-year Civil Engineering studen...
# 1  Undergraduate Researcher — Shah Lab September ...
# 2  Sep 2022 - Apr 2025 m Global Key Account Manag...
# 3  PET GROOMER, Professional and personable Pet G...
# 4  Practical Event Coordinator with 5  years expe...
# 5  John Huber, UX Designer, Proactive and detaile...
# 6  Laboratory Inventory Assistant at Dunrea Labor...

# %% [markdown]
# # creating a custom NER model

# %%
# Load a spacy model and chekc if it has ner

import spacy
nlp=spacy.load('en_core_web_sm')

nlp.pipe_names
# Out:
# ['tok2vec', 'tagger', 'parser', 'attribute_ruler', 'lemmatizer', 'ner']

# %%
ner=nlp.get_pipe("ner")

# training data
TRAIN_DATA = [
              ("Walmart is a leading e-commerce company", {"entities": [(0, 7, "ORG")]}),
              ("I reached Chennai yesterday.", {"entities": [(19, 28, "GPE")]}),
              ("I recently ordered a book from Amazon", {"entities": [(24,32, "ORG")]}),
              ("I was working at Jumia", {"entities": [(17,23, "ORG")]}),
              ("I ordered this from ShopClues", {"entities": [(20,29, "ORG")]}),
              ("Altran can be ordered in Amazon ", {"entities": [(0,6, "ORG")]}),
              ("I was born in Washinton", {"entities": [(14,22, "GPE")]}),
              ("I was born in New York", {"entities": [(14,22, "GPE")]}),
              ("I bought a present from Japan", {"entities": [(24,29, "GPE")]}),
              ("I work in Sony company", {"entities": [(10,14, "ORG")]}),
              ("I rented a tent in Agadir", {"entities": [(19,25, "GPE")]}),
              ("I worked before in Innovation Insitute", {"entities": [(19,38, "ORG")]}),
              ("I graduated from Engineering University", {"entities": [(17,39, "ORG")]}),
              ("I got certificated from GoMyCode", {"entities": [(25,33, "ORG")]}),
              ("certified data scientist From Udemy", {"entities": [(30,35, "ORG")]}),
              ("Flipkart started it's journey from zero", {"entities": [(0,8, "ORG")]}),
              ("I recently ordered from Max", {"entities": [(24,27, "ORG")]}),
              ("Flipkart is recognized as leader in market",{"entities": [(0,8, "ORG")]}),

              ("Master Degree on Industrial engineering from EMSI",{"entities": [(46,49, "ORG")]}),
              ("Amazon Warehouse Associate at Amazon",{"entities": [(30,36, "ORG")]}),
              ("Los Angeles, CA 90291",{"entities": [(0,12, "GPE")]}),
              ("1515 Pacific Ave, Los Angeles, CA 90291, United",{"entities": [(18,29, "GPE")]}),
              ("Event Coordinator, Bright Event Rentals, Florida",{"entities": [(19,39, "ORG")]}),
              ("A in Hotel & Event Management, University of New York, Brooklyn",{"entities": [(31,53, "ORG")]}),
              ("Amazon Warehouse Associate at Amazon, Miami Gardens",{"entities": [(38,51, "GPE")]}),
              ("Laboratory Inventory Assistant at Dunrea Laboratories",{"entities": [(34,53, "ORG")]}),
              ("Associates Degree in Logistics and Supply Chain Fundamentals,Atlanta Technical College, Atlanta",{"entities": [(61,86, "ORG")]}),
              ("UX Designer, Real Vision Group",{"entities": [(13,30, "ORG")]}),
              ("Masters Degree in Human Computer Interaction (HCI), Pratt Institute",{"entities": [(52,67, "ORG")]}),
              ("Civil Engineer Intern, Bricksburg Construction, Bricksburg, DK",{"entities": [(23,46, "ORG")]}),

              ("I recently ordered from Swiggy", {"entities": [(24,29, "ORG")]})
              ]

# %%
for _, annotations in TRAIN_DATA:
  for ent in annotations.get("entities"):
    ner.add_label(ent[2])

# %%
# Disable pipeline components you dont need to change
pipe_exceptions = ["ner", "trf_wordpiecer", "trf_tok2vec"]
unaffected_pipes = [pipe for pipe in nlp.pipe_names if pipe not in pipe_exceptions]

# %%
# Import requirements
import random
from spacy.util import minibatch, compounding
from pathlib import Path
from spacy.training.example import Example

# TRAINING THE MODEL
with nlp.disable_pipes(*unaffected_pipes):

  epochs = 30
  # Training for 30 iterations
  for epoch in range(epochs):

    # shuufling examples  before every iteration
    random.shuffle(TRAIN_DATA)
    losses = {}

    # batch up the examples using spaCy's minibatch
    batches = minibatch(TRAIN_DATA, size=compounding(4.0, 32.0, 1.001))
    for batch in batches:
        
        #texts, annotations = zip(*batch)

        for text, annotations in  batch:
                examples = []
                doc = nlp.make_doc(text)
                example = Example.from_dict(doc, annotations)
                examples.append(example)
                nlp.update(examples, drop = 0.15, losses = losses)
        
        #nlp.update(
                    #texts,  # batch of texts
                    #annotations,  # batch of annotations
                    #drop=0.5,  # dropout - make it harder to memorise data
                    #losses=losses,)
        print("Losses", losses)
# Out:
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I recently ordered from Swiggy" with entities "[(24, 29, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': np.float32(7.267045)}
# Losses {'ner': np.float32(10.561862)}
# Losses {'ner': np.float32(20.034132)}
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I recently ordered a book from Amazon" with entities "[(24, 32, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': np.float32(24.029247)}
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "Master Degree on Industrial engineering from EMSI" with entities "[(46, 49, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': np.float32(29.271894)}
# Losses {'ner': np.float32(31.368517)}
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I reached Chennai yesterday." with entities "[(19, 28, 'GPE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I was working at Jumia" with entities "[(17, 23, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I got certificated from GoMyCode" with entities "[(25, 33, 'ORG')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': np.float32(31.86962)}
# C:\Users\dell\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.12_qbz5n2kfra8p0\LocalCache\local-packages\Python312\site-packages\spacy\training\iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I was born in Washinton" with entities "[(14, 22, 'GPE')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# Losses {'ner': np.float32(34.348907)}
# Losses {'ner': np.float32(1.7095693)}
# Losses {'ner': np.float32(2.523291)}
# Losses {'ner': np.float32(2.5239503)}
# Losses {'ner': np.float32(2.5469394)}
# Losses {'ner': np.float32(2.8964846)}
# Losses {'ner': np.float32(4.649349)}
# Losses {'ner': np.float32(8.618615)}
# Losses {'ner': np.float32(8.653647)}
# Losses {'ner': np.float32(0.093576)}
# Losses {'ner': np.float32(3.340423)}
# Losses {'ner': np.float32(3.3877718)}
# Losses {'ner': np.float32(3.516416)}
# Losses {'ner': np.float32(3.5228133)}
# Losses {'ner': np.float32(5.5205765)}
# Losses {'ner': np.float32(7.4518404)}
# Losses {'ner': np.float32(8.291346)}
# Losses {'ner': np.float32(0.051971734)}
# Losses {'ner': np.float32(2.1809897)}
# Losses {'ner': np.float32(2.1832328)}
# Losses {'ner': np.float32(6.713514)}
# Losses {'ner': np.float32(6.717557)}
# Losses {'ner': np.float32(6.71756)}
# Losses {'ner': np.float32(6.72195)}
# Losses {'ner': np.float32(6.8079767)}
# Losses {'ner': np.float32(2.3739502)}
# Losses {'ner': np.float32(2.3739502)}
# Losses {'ner': np.float32(2.3743856)}
# Losses {'ner': np.float32(3.1890368)}
# Losses {'ner': np.float32(3.189417)}
# Losses {'ner': np.float32(3.4842598)}
# Losses {'ner': np.float32(3.5582879)}
# Losses {'ner': np.float32(3.5582879)}
# Losses {'ner': np.float32(0.0022436613)}
# Losses {'ner': np.float32(1.9925448)}
# Losses {'ner': np.float32(3.1495771)}
# Losses {'ner': np.float32(3.1495771)}
# Losses {'ner': np.float32(3.158639)}
# Losses {'ner': np.float32(3.1587026)}
# Losses {'ner': np.float32(3.2719064)}
# Losses {'ner': np.float32(3.2719064)}
# Losses {'ner': np.float32(0.0060596652)}
# Losses {'ner': np.float32(0.0060602203)}
# Losses {'ner': np.float32(0.0060602208)}
# Losses {'ner': np.float32(0.0069123283)}
# Losses {'ner': np.float32(0.0069127185)}
# Losses {'ner': np.float32(0.04120306)}
# Losses {'ner': np.float32(0.04120334)}
# Losses {'ner': np.float32(2.0245786)}
# Losses {'ner': np.float32(1.0295779e-07)}
# Losses {'ner': np.float32(1.6043688)}
# Losses {'ner': np.float32(1.6044141)}
# Losses {'ner': np.float32(1.6044186)}
# Losses {'ner': np.float32(1.6049994)}
# Losses {'ner': np.float32(1.6837859)}
# Losses {'ner': np.float32(1.6837862)}
# Losses {'ner': np.float32(1.683982)}
# Losses {'ner': np.float32(1.8509212)}
# Losses {'ner': np.float32(1.8670728)}
# Losses {'ner': np.float32(1.8670728)}
# Losses {'ner': np.float32(1.8670728)}
# Losses {'ner': np.float32(1.8670748)}
# Losses {'ner': np.float32(1.8670748)}
# Losses {'ner': np.float32(1.8760895)}
# Losses {'ner': np.float32(2.9003863)}
# Losses {'ner': np.float32(5.913832e-06)}
# Losses {'ner': np.float32(6.641994e-05)}
# Losses {'ner': np.float32(0.000105361694)}
# Losses {'ner': np.float32(0.00010568018)}
# Losses {'ner': np.float32(0.00021253419)}
# Losses {'ner': np.float32(1.2162077)}
# Losses {'ner': np.float32(1.2162077)}
# Losses {'ner': np.float32(1.2174131)}
# Losses {'ner': np.float32(0.00025549295)}
# Losses {'ner': np.float32(0.00025773965)}
# Losses {'ner': np.float32(0.0002578137)}
# Losses {'ner': np.float32(0.00025828643)}
# Losses {'ner': np.float32(0.00025855727)}
# Losses {'ner': np.float32(0.00057104067)}
# Losses {'ner': np.float32(0.0005716473)}
# Losses {'ner': np.float32(0.00057169027)}
# Losses {'ner': np.float32(3.7624846e-05)}
# Losses {'ner': np.float32(5.709019e-05)}
# Losses {'ner': np.float32(0.002496072)}
# Losses {'ner': np.float32(0.08962065)}
# Losses {'ner': np.float32(0.08962066)}
# Losses {'ner': np.float32(0.08962067)}
# Losses {'ner': np.float32(0.08962112)}
# Losses {'ner': np.float32(0.08962117)}
# Losses {'ner': np.float32(7.593265e-09)}
# Losses {'ner': np.float32(3.9551233e-07)}
# Losses {'ner': np.float32(1.9923594)}
# Losses {'ner': np.float32(1.9923604)}
# Losses {'ner': np.float32(1.9923604)}
# Losses {'ner': np.float32(1.9923604)}
# Losses {'ner': np.float32(2.0374699)}
# Losses {'ner': np.float32(2.0375082)}
# Losses {'ner': np.float32(1.0218739e-09)}
# Losses {'ner': np.float32(4.933111e-08)}
# Losses {'ner': np.float32(0.00064900966)}
# Losses {'ner': np.float32(0.0035830312)}
# Losses {'ner': np.float32(0.003583044)}
# Losses {'ner': np.float32(0.0035833558)}
# Losses {'ner': np.float32(0.0035854876)}
# Losses {'ner': np.float32(0.0036011608)}
# Losses {'ner': np.float32(4.6372323e-05)}
# Losses {'ner': np.float32(6.6835586e-05)}
# Losses {'ner': np.float32(8.5357286e-05)}
# Losses {'ner': np.float32(8.5400105e-05)}
# Losses {'ner': np.float32(8.901515e-05)}
# Losses {'ner': np.float32(0.0068343715)}
# Losses {'ner': np.float32(0.0068805944)}
# Losses {'ner': np.float32(0.0068880245)}
# Losses {'ner': np.float32(4.143734e-08)}
# Losses {'ner': np.float32(0.0006346675)}
# Losses {'ner': np.float32(0.0006346924)}
# Losses {'ner': np.float32(0.0023172183)}
# Losses {'ner': np.float32(0.0023172193)}
# Losses {'ner': np.float32(0.0023218037)}
# Losses {'ner': np.float32(0.0023218046)}
# Losses {'ner': np.float32(0.0023218088)}
# Losses {'ner': np.float32(4.4813472e-08)}
# Losses {'ner': np.float32(3.235427e-07)}
# Losses {'ner': np.float32(4.6513043e-05)}
# Losses {'ner': np.float32(0.00013838903)}
# Losses {'ner': np.float32(0.0001457021)}
# Losses {'ner': np.float32(0.00014596473)}
# Losses {'ner': np.float32(0.00014604404)}
# Losses {'ner': np.float32(0.00014604426)}
# Losses {'ner': np.float32(3.363619e-06)}
# Losses {'ner': np.float32(3.3787728e-06)}
# Losses {'ner': np.float32(1.3819099e-05)}
# Losses {'ner': np.float32(1.6170623e-05)}
# Losses {'ner': np.float32(1.7741217e-05)}
# Losses {'ner': np.float32(0.0016428353)}
# Losses {'ner': np.float32(0.0016428607)}
# Losses {'ner': np.float32(0.0016428978)}
# Losses {'ner': np.float32(4.7515695e-07)}
# Losses {'ner': np.float32(5.033548e-07)}
# Losses {'ner': np.float32(1.8260374e-06)}
# Losses {'ner': np.float32(1.8310856e-06)}
# Losses {'ner': np.float32(1.8312498e-06)}
# Losses {'ner': np.float32(3.6365368e-06)}
# Losses {'ner': np.float32(0.0064512454)}
# Losses {'ner': np.float32(0.006451427)}
# Losses {'ner': np.float32(8.4180163e-10)}
# Losses {'ner': np.float32(4.9522273e-06)}
# Losses {'ner': np.float32(5.059443e-06)}
# Losses {'ner': np.float32(5.191434e-06)}
# Losses {'ner': np.float32(0.00014166115)}
# Losses {'ner': np.float32(0.00014226449)}
# Losses {'ner': np.float32(0.00014226553)}
# Losses {'ner': np.float32(0.00014733944)}
# Losses {'ner': np.float32(5.485668e-06)}
# Losses {'ner': np.float32(5.938072e-06)}
# Losses {'ner': np.float32(5.9451145e-06)}
# Losses {'ner': np.float32(0.0008880929)}
# Losses {'ner': np.float32(0.0008882087)}
# Losses {'ner': np.float32(0.00088821264)}
# Losses {'ner': np.float32(0.00088821567)}
# Losses {'ner': np.float32(0.00088849745)}
# Losses {'ner': np.float32(1.6228564e-07)}
# Losses {'ner': np.float32(1.659114e-07)}
# Losses {'ner': np.float32(1.7849639e-07)}
# Losses {'ner': np.float32(2.1178852e-07)}
# Losses {'ner': np.float32(0.00012074658)}
# Losses {'ner': np.float32(0.00012108403)}
# Losses {'ner': np.float32(0.000127066)}
# Losses {'ner': np.float32(0.00016367954)}
# Losses {'ner': np.float32(1.8057412e-09)}
# Losses {'ner': np.float32(9.2330936e-08)}
# Losses {'ner': np.float32(1.7435339e-07)}
# Losses {'ner': np.float32(1.7615714e-07)}
# Losses {'ner': np.float32(3.7791287e-06)}
# Losses {'ner': np.float32(4.44238e-06)}
# Losses {'ner': np.float32(4.5024794e-06)}
# Losses {'ner': np.float32(4.524914e-06)}
# Losses {'ner': np.float32(7.5631505e-08)}
# Losses {'ner': np.float32(8.0921666e-08)}
# Losses {'ner': np.float32(2.6191697e-07)}
# Losses {'ner': np.float32(2.633635e-07)}
# Losses {'ner': np.float32(0.00019685116)}
# Losses {'ner': np.float32(0.00019688587)}
# Losses {'ner': np.float32(0.0001969345)}
# Losses {'ner': np.float32(0.00019693452)}
# Losses {'ner': np.float32(3.3316856e-09)}
# Losses {'ner': np.float32(8.580523e-09)}
# Losses {'ner': np.float32(1.3844905e-07)}
# Losses {'ner': np.float32(1.4657661e-07)}
# Losses {'ner': np.float32(3.1957921e-07)}
# Losses {'ner': np.float32(3.1959542e-07)}
# Losses {'ner': np.float32(3.196426e-07)}
# Losses {'ner': np.float32(3.627842e-07)}
# Losses {'ner': np.float32(0.00010161339)}
# Losses {'ner': np.float32(0.00010215559)}
# Losses {'ner': np.float32(0.000102155864)}
# Losses {'ner': np.float32(0.000102179176)}
# Losses {'ner': np.float32(0.000102459555)}
# Losses {'ner': np.float32(0.000102468766)}
# Losses {'ner': np.float32(0.00010249617)}
# Losses {'ner': np.float32(0.00010250226)}
# Losses {'ner': np.float32(1.0851398e-08)}
# Losses {'ner': np.float32(1.5043462e-08)}
# Losses {'ner': np.float32(3.2750133e-08)}
# Losses {'ner': np.float32(3.5638544e-07)}
# Losses {'ner': np.float32(4.1064482e-07)}
# Losses {'ner': np.float32(1.1005234e-06)}
# Losses {'ner': np.float32(1.1288785e-06)}
# Losses {'ner': np.float32(1.1405683e-06)}
# Losses {'ner': np.float32(3.234622e-07)}
# Losses {'ner': np.float32(3.2367933e-07)}
# Losses {'ner': np.float32(4.0544448e-05)}
# Losses {'ner': np.float32(0.001198054)}
# Losses {'ner': np.float32(0.0011980548)}
# Losses {'ner': np.float32(0.0011980549)}
# Losses {'ner': np.float32(0.001198055)}
# Losses {'ner': np.float32(0.0011980989)}
# Losses {'ner': np.float32(1.0809885e-09)}
# Losses {'ner': np.float32(3.5685126e-08)}
# Losses {'ner': np.float32(5.8166723e-08)}
# Losses {'ner': np.float32(1.589593e-05)}
# Losses {'ner': np.float32(1.5926287e-05)}
# Losses {'ner': np.float32(1.6285487e-05)}
# Losses {'ner': np.float32(1.6327174e-05)}
# Losses {'ner': np.float32(1.7095175e-05)}
# Losses {'ner': np.float32(1.16915735e-05)}
# Losses {'ner': np.float32(1.1752478e-05)}
# Losses {'ner': np.float32(1.2131707e-05)}
# Losses {'ner': np.float32(0.004522817)}
# Losses {'ner': np.float32(0.004522983)}
# Losses {'ner': np.float32(0.0045294766)}
# Losses {'ner': np.float32(0.004635079)}
# Losses {'ner': np.float32(0.004741362)}

# %%
# saving model

output_dir='NERScapy_model'
nlp.to_disk(output_dir)

# %%
# Test data with expected entities

TEST_DATA = [
    ("Marjane is a big place to shopping", {"entities": [(0,7,"ORG")]}),
    ("I visited Korea this year", {"entities": [(11, 16, "GPE")]}),
    ("I bought some new gadgets from Aliexpress", {"entities": [(39, 49, "ORG")]}),
    ("I am driving a Toyota", {"entities": [(21, 27, "ORG")]}),
    ("I purchased a new shoes from Cotsco", {"entities": [(36, 42, "ORG")]}),
    ("washing machine are available in Netflix", {"entities": [(30, 37, "ORG")]}),
    ("I work at Infotel", {"entities": [(10, 17, "ORG")]}),
    ("I worked before in Segula", {"entities": [(20, 26, "ORG")]}),
    ("I bought a fancy dress from ZARA", {"entities": [(36, 41, "ORG")]}),
    ("I received as a present Nikon camera", {"entities": [(23, 28, "ORG")]}),
]

# %% [markdown]
# # creating a function to evaluate the model

# %%
from sklearn.metrics import precision_score, recall_score, f1_score
    
def evaluate_model(test_data):

    nlp= spacy.load('NERScapy_model')

    true_entities = []
    pred_entities = []
    
    for text, annotations in test_data:
        doc = nlp(text)  # Use the full nlp object to obtain a Doc
        true_entities.extend(annotations["entities"])

        # Extract predicted entities
        pred_entities_in_text = [(ent.text, ent.label_) for ent in doc.ents]
        pred_entities.extend(pred_entities_in_text)

    x1=len(true_entities)
    x2=len(pred_entities)

    for i in range((x1-x2)-1,len(true_entities)-1):
        pred_entities.append('Nan')
    

    # Prepare labels for metrics
    y_true_labels = [ent[2] for ent in true_entities]
    y_pred_labels = [ent[1] for ent in pred_entities]


    # Handle cases with no predictions
    if not y_pred_labels:
        print("No predictions made. Precision, recall, and F1 score cannot be defined.")
        return

    # Calculate metrics
    precision = precision_score(y_true_labels, y_pred_labels, average='weighted', zero_division=0)
    recall = recall_score(y_true_labels, y_pred_labels, average='weighted', zero_division=0)
    f1 = f1_score(y_true_labels, y_pred_labels, average='weighted', zero_division=0)

    print(f"Precision: {precision:.2f}")
    print(f"Recall: {recall:.2f}")
    print(f"F1 Score: {f1:.2f}")

# %%
# Evaluating the model performance

evaluate_model(TEST_DATA)
# Out:
# Precision: 0.72
# Recall: 0.40
# F1 Score: 0.51

# %%
# Save the  model to directory
print("Saved model as : ", output_dir)
# Out:
# Saved model as :  NERScapy_model

# %% [markdown]
# # using the model to categorize dataset entities

# %%
#using model with our parsed CVs

def extract_entities(text):

    nlp = spacy.load('NERScapy_model')

    list_org=[]

    try :
        doc = nlp(text)
        list_org=[ent.text for ent in doc.ents if ent.label_=='ORG']
        return ', '.join(list_org)

    except:
        return list_org

# %%
data['edu_organisations']=[extract_entities(i) for i in data['education']]
data['exp_organisations']=[extract_entities(i) for i in data['experience']]

data
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                       linkedin.com/emmetbrickowsk1
# 1                                       no URL found
# 2  resumeviking.com/templates, xeOrlukd.com/24QSB...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  solidworks, english, networking, autocad, milling
# 1                                      python, excel
# 2  english, strategic planning, spanish, networki...
# 3  cleaning, dog training, cat grooming, dog groo...
# 4                     french, english, visual design
# 5                                css, ux, javascript
# 6            cleaning, english, spanish, mathematics
#
#                                            education  \
# 0  LEGO City University LEGO City, DK, Bachelor o...
# 1  Process Engineering Intern June 2021 - Septemb...
# 2  Bachelor Degree in Advertising and Marketing, ...
# 3                 GED, Nashville High, Nashville, TN
# 4  e Managed and coordinated 160  events per year...
# 5  Masters Degree in Human Computer Interaction H...
# 6  on packing records. Completed a certificate in...
#
#                                           experience  \
# 0  OBJECTIVE Fourth-year Civil Engineering studen...
# 1  Undergraduate Researcher — Shah Lab September ...
# 2  Sep 2022 - Apr 2025 m Global Key Account Manag...
# 3  PET GROOMER, Professional and personable Pet G...
# 4  Practical Event Coordinator with 5  years expe...
# 5  John Huber, UX Designer, Proactive and detaile...
# 6  Laboratory Inventory Assistant at Dunrea Labor...
#
#                                    edu_organisations  \
# 0  LEGO City University LEGO City, Principles of ...
# 1
# 2  University of Denver, Business College of New ...
# 3
# 4        University of New York, Business Management
# 5                    Pratt Institute New York, HTMLS
# 6  Atlanta Technical College, Southern New Hampsh...
#
#                                    exp_organisations
# 0  Bricksburg Construction, Bachelor of Science i...
# 1
# 2                            Presidion Petroleum, TX
# 3  Pet Groomer, Pet Groomer, Pet Groomer, Pet Gro...
# 4        Bright Event Rentals, Classic Party Rentals
# 5  Real Vision Group New York, SP Global New York...
# 6                                Dunrea Laboratories

# %%
data.to_csv('processNER.csv',na_rep='NaN',index=False)

# %%
df=pd.read_csv('processNER.csv')

df.fillna('unknown', inplace=True)

df
# Out:
#                          file             name              location  \
# 0   EPS-Civil-Engineering.pdf               DK            Bricksburg
# 1             EPSExamples.pdf    no name found     no location found
# 2           Example-1-PDF.pdf   Michelle Smith           Los Angeles
# 3       resume-example-12.pdf    Edmond Connor               Orlando
# 4  Resume-Template-Modern.pdf  Templates Build           Los Angeles
# 5                  resume.pdf       John Huber              New York
# 6         Stockholm-Resum.pdf     Jason Miller  Warehouse Sanitation
#
#                  email                  phone  \
# 0  ebrickowski@lcu.edu       123 456 - 7890
# 1       no email found  no phone number found
# 2      email@email.com          541 754-3010
# 3    example@email.com       890-555-0401\n\n
# 4      email@email.com         3868683442\n\n
# 5      email@email.com           890-555-0401
# 6      email@email.com           3868683442\n
#
#                                                Links  \
# 0                       linkedin.com/emmetbrickowsk1
# 1                                       no URL found
# 2  resumeviking.com/templates, xeOrlukd.com/24QSB...
# 3                                       no URL found
# 4                                       no URL found
# 5                                       no URL found
# 6                                       no URL found
#
#                                               skills  \
# 0  solidworks, english, networking, autocad, milling
# 1                                      python, excel
# 2  english, strategic planning, spanish, networki...
# 3  cleaning, dog training, cat grooming, dog groo...
# 4                     french, english, visual design
# 5                                css, ux, javascript
# 6            cleaning, english, spanish, mathematics
#
#                                            education  \
# 0  LEGO City University LEGO City, DK, Bachelor o...
# 1  Process Engineering Intern June 2021 - Septemb...
# 2  Bachelor Degree in Advertising and Marketing, ...
# 3                 GED, Nashville High, Nashville, TN
# 4  e Managed and coordinated 160  events per year...
# 5  Masters Degree in Human Computer Interaction H...
# 6  on packing records. Completed a certificate in...
#
#                                           experience  \
# 0  OBJECTIVE Fourth-year Civil Engineering studen...
# 1  Undergraduate Researcher — Shah Lab September ...
# 2  Sep 2022 - Apr 2025 m Global Key Account Manag...
# 3  PET GROOMER, Professional and personable Pet G...
# 4  Practical Event Coordinator with 5  years expe...
# 5  John Huber, UX Designer, Proactive and detaile...
# 6  Laboratory Inventory Assistant at Dunrea Labor...
#
#                                    edu_organisations  \
# 0  LEGO City University LEGO City, Principles of ...
# 1                                            unknown
# 2  University of Denver, Business College of New ...
# 3                                            unknown
# 4        University of New York, Business Management
# 5                    Pratt Institute New York, HTMLS
# 6  Atlanta Technical College, Southern New Hampsh...
#
#                                    exp_organisations
# 0  Bricksburg Construction, Bachelor of Science i...
# 1                                            unknown
# 2                            Presidion Petroleum, TX
# 3  Pet Groomer, Pet Groomer, Pet Groomer, Pet Gro...
# 4        Bright Event Rentals, Classic Party Rentals
# 5  Real Vision Group New York, SP Global New York...
# 6                                Dunrea Laboratories
